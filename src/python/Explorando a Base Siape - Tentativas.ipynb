# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from IPython.display import display, Markdown
import seaborn as sns
# Out:
# /home/carolcardoso/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Especifique o caminho para o seu arquivo CSV
caminho_arquivo = '../../dados/dados_siape_consolidado/uorg_exercicio/cadastro_siape_consolidado_uorg_org_regime_mes_ano_completo-2021-2023.csv'

df = pd.read_csv(caminho_arquivo)

# %%
df['ano'].unique()

# %%
df['ano_mes'] = df['ano'].astype(str) + '-' + df['mes'].astype(str).str.zfill(2)

# %%
def grafico_regime_juridico (ano, mes):

    display (Markdown(f'# Ano: {ano}'))
    
    # Supondo que df seja o seu DataFrame
    df_filtrado = df[(df['ano'] == ano) & (df['mes'] == mes)]
    grupo_contagem = df_filtrado.groupby(['REGIME_JURIDICO'])['Contagem'].sum().reset_index()
    
    # Cria o gráfico de barras e adiciona rótulos (labels)
    ax = grupo_contagem.plot.bar(x='REGIME_JURIDICO', y='Contagem', legend=False)
    ax.bar_label(ax.containers[0])
    
    # Mostra o gráfico
    plt.show()

# %%
for ano in range(2013, 2024):
    grafico_regime_juridico(ano, 1)

# %%
df[
    (df['ano'] == 2023) &
    (df['mes'] == 11)
]

# %%
# Lista de palavras-chave para filtrar as empresas
palavras_chave = ['regente', 'pintor']

# Filtrar apenas os registros onde 'REGIME JURIDICO UNICO' está presente na coluna 'REGIME_JURIDICO'
df_servidores = df[df['REGIME_JURIDICO'].str.lower().str.contains('regime juridico unico', case=False, na=False) & 
                    df['ORGSUP_EXERCICIO'].str.lower().str.contains('ministério da economia', case=False, na=False) &
                    df['DESCRICAO_CARGO']
                ].sort_values(by=['ORGSUP_EXERCICIO', 'REGIME_JURIDICO', 'DESCRICAO_CARGO', 'ano'])

# df_servidores.groupby(['ORGSUP_EXERCICIO','REGIME_JURIDICO', 'ano_mes'])['Contagem'].mean().reset_index()
df_servidores.groupby(['ORGSUP_EXERCICIO','REGIME_JURIDICO', 'ano'])['Contagem'].mean().reset_index()

# %%
# Lista de palavras-chave para filtrar as empresas
palavras_chave = ['regente', 'pintor']

# Filtrar apenas os registros onde 'REGIME JURIDICO UNICO' está presente na coluna 'REGIME_JURIDICO'
df_servidores = df[df['REGIME_JURIDICO'].str.lower().str.contains('regime juridico unico', case=False, na=False) & 
                    df['ORGSUP_EXERCICIO'].str.lower().str.contains('ministério da economia', case=False, na=False)
                ].sort_values(by=['ORGSUP_EXERCICIO', 'REGIME_JURIDICO', 'ano'])

# df_servidores.groupby(['ORGSUP_EXERCICIO','REGIME_JURIDICO', 'ano_mes'])['Contagem'].mean().reset_index()
df_servidores.groupby(['ORGSUP_EXERCICIO','REGIME_JURIDICO', 'ano'])['Contagem'].mean().reset_index()

# %%
df['DESCRICAO_CARGO'].sample(10)

# %%
if True and True and False:
    print ("entrou")
else:
    print ("não entrou")

# %%
(df['REGIME_JURIDICO'].str.lower().str.contains('regime juridico unico', case=False, na=False) &
df['ORGSUP_EXERCICIO'].str.lower().str.contains('ministério da economia', case=False, na=False) &
# Out:
#   Cell In[28], line 2
#     df['ORGSUP_EXERCICIO'].str.lower().str.contains('ministério da economia', case=False, na=False)
#                                                                                                    ^
# SyntaxError: incomplete input

# %%
df_servidores.head(10)

# %%
# Criar gráfico interativo de linha usando o Plotly Express
fig = px.line(df_servidores, x='ano', y='Contagem', markers=True, line_shape='linear',
              title='Contagem dos servidores por órgão ao longo dos anos')

# Ajustar configuração do eixo X para mostrar todos os anos
fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))

fig.update_layout(width=1000, height=750)

# Exibir gráfico
fig.show()

# %%
# Filtrar apenas os registros onde 'REGIME JURIDICO UNICO' está presente na coluna 'REGIME_JURIDICO'
df_servidores = df[df['REGIME_JURIDICO'].str.lower().str.contains('regime juridico unico', case=False, na=False)]

df_contagem_combinacoes = df_servidores.groupby(['ORGSUP_EXERCICIO','REGIME_JURIDICO', 'ano'])['Contagem'].mean().reset_index()

# Agrupe pelo REGIME_JURIDICO e ordene dentro de cada grupo pela coluna ESTAGIO
df_agrupado_ordenado = df_contagem_combinacoes.sort_values(by=['ORGSUP_EXERCICIO', 'REGIME_JURIDICO', 'ano'])

# Criar gráfico interativo de linha usando o Plotly Express
fig = px.line(df_agrupado_ordenado, x='ano', y='Contagem', color='ORGSUP_EXERCICIO', markers=True, line_shape='linear',
              title='Contagem dos servidores por órgão ao longo dos anos')

# Ajustar configuração do eixo X para mostrar todos os anos
fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))

fig.update_layout(width=1000, height=750)

# Exibir gráfico
fig.show()

# %% [markdown]
# # NÃO EXCLUÍMOS CPFs REPETIDOS!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# # Contagem dos servidores por órgão ao longo dos anos

# %%
# Filtrar apenas os registros onde 'REGIME JURIDICO UNICO' está presente na coluna 'REGIME_JURIDICO'
df_servidores = df[df['REGIME_JURIDICO'].str.lower().str.contains('regime juridico unico', case=False, na=False)]

df_contagem_combinacoes = df_servidores.groupby(['ORGSUP_EXERCICIO','REGIME_JURIDICO', 'ano', 'mes'])['Contagem'].sum().reset_index()

# Agrupe pelo REGIME_JURIDICO e ordene dentro de cada grupo pela coluna ESTAGIO
df_agrupado_ordenado = df_contagem_combinacoes.sort_values(by=['ORGSUP_EXERCICIO', 'REGIME_JURIDICO', 'ano', 'mes'])

# Criar gráfico interativo de linha usando o Plotly Express
fig = px.line(df_agrupado_ordenado, x='ano', y='Contagem', color='ORGSUP_EXERCICIO', markers=True, line_shape='linear',
              title='Contagem dos servidores por órgão ao longo dos anos')

# Ajustar configuração do eixo X para mostrar todos os anos
fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))

fig.update_layout(width=1000, height=750)

# Exibir gráfico
fig.show()

# %%
def grafico_servidores_por_orgao (df_orgaos, ano, mes):

    display (Markdown(f'# Ano: {ano}'))
    
    # Supondo que df seja o seu DataFrame
    df_filtrado = df_orgaos[(df_orgaos['ano'] == ano) & (df_orgaos['mes'] == mes)]
    
    tamanho = df_filtrado['REGIME_JURIDICO'].count()
    
    if tamanho == 0:
        display(f'O dataframe para {mes} de {ano} não tem registros')

    else:
        grupo_contagem = df_filtrado.groupby(['REGIME_JURIDICO'])['Contagem'].sum().reset_index()
    
        # Cria o gráfico de barras e adiciona rótulos (labels)
        ax = grupo_contagem.plot.bar(x='REGIME_JURIDICO', y='Contagem', legend=False)
        ax.bar_label(ax.containers[0])
        
        # Mostra o gráfico
        plt.show()

# %%
for ano in range(2012, 2024):
    grafico_servidores_por_orgao(df, ano, 1)

# %%
df_janeiro = df[df['mes'] == 1]

# %%
display(df.info())
display(df_janeiro.info())

# %%
df_fazenda = df[df["ORGSUP_EXERCICIO"].str.contains('fazenda', case=False, na=False)]

# %%
df_fazenda

# %%
def grafico_servidores_por_orgao_e_ano (df_orgaos, orgaos_escolhidos):

    df_filtrado = df_orgaos[
                        df_orgaos["REGIME_JURIDICO"].str.contains("regime juridico unico", na=False, case=False) &
                        df_orgaos["ORG_EXERCICIO"].str.contains('|'.join(orgaos_escolhidos), na=False, case=False)
                    ]
    display(df_filtrado['ORG_EXERCICIO'].unique())
    # Supondo que df seja o seu DataFrame    
    tamanho = df_filtrado['REGIME_JURIDICO'].count()
    
    if tamanho == 0:
        
        display(f'O dataframe não tem registros')

    else:
        df_grupo_contagem = df_filtrado.groupby(['ORG_EXERCICIO','ano'])['Contagem'].sum().reset_index()

        # Criar gráfico interativo de linha usando o Plotly Express
        fig = px.line(df_grupo_contagem, x='ano', y='Contagem', color='ORG_EXERCICIO',
                      markers=True, line_shape='linear',
                      title='Contagem de servidores nos 5 órgãos escolhidos ao longo dos anos')
        
        # Ajustar configuração do eixo X para mostrar todos os anos
        fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))
        
        fig.update_layout(width=1000, height=750)
        
        # Exibir gráfico
        fig.show()

orgaos_escolhidos = ['economia']

grafico_servidores_por_orgao_e_ano(df_janeiro, orgaos_escolhidos)

# %%
def grafico_servidores_por_orgao_e_ano (df_orgaos, orgaos_escolhidos):

    df_filtrado = df_orgaos[
                        df_orgaos["REGIME_JURIDICO"].str.contains("regime juridico unico", na=False, case=False) &
                        df_orgaos["ORG_EXERCICIO"].str.contains('|'.join(orgaos_escolhidos), na=False, case=False)
                    ]
    display(df_filtrado['ORG_EXERCICIO'].unique())
    # Supondo que df seja o seu DataFrame    
    tamanho = df_filtrado['REGIME_JURIDICO'].count()
    
    if tamanho == 0:
        
        display(f'O dataframe não tem registros')

    else:
        df_grupo_contagem = df_filtrado.groupby(['ORG_EXERCICIO','ano'])['Contagem'].sum().reset_index()

        # Criar gráfico interativo de linha usando o Plotly Express
        fig = px.line(df_grupo_contagem, x='ano', y='Contagem', color='ORG_EXERCICIO',
                      markers=True, line_shape='linear',
                      title='Contagem de servidores nos 5 órgãos escolhidos ao longo dos anos')
        
        # Ajustar configuração do eixo X para mostrar todos os anos
        fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))
        
        fig.update_layout(width=1000, height=750)
        
        # Exibir gráfico
        fig.show()

orgaos_escolhidos = ['economia']

grafico_servidores_por_orgao_e_ano(df_janeiro, orgaos_escolhidos)

# %%
def grafico_servidores_por_orgao_ano_mes (df_orgaos, orgaos_escolhidos):

    df_regime_juridico_unico = df_orgaos[
                        df_orgaos["REGIME_JURIDICO"].str.contains("regime juridico unico", na=False, case=False) &
                        df_orgaos["ORG_EXERCICIO"].str.contains('|'.join(orgaos_escolhidos), na=False, case=False)
                    ]

    df_estagio = df_orgaos[
                        df_orgaos["REGIME_JURIDICO"].str.contains("estag", na=False, case=False) &
                        df_orgaos["ORG_EXERCICIO"].str.contains('|'.join(orgaos_escolhidos), na=False, case=False)
                    ]

    meses = df_orgaos['ano_mes'].unique()   

    
    display(df_estagio['ORG_EXERCICIO'].unique())
    # Supondo que df seja o seu DataFrame    
    tamanho = df_estagio['REGIME_JURIDICO'].count()
    
    if tamanho == 0:
        
        display(f'O dataframe não tem registros')

    else:
        df_grupo_contagem = df_estagio.groupby(['ORG_EXERCICIO','ano_mes'])['Contagem'].sum().reset_index()

        # Criar gráfico interativo de linha usando o Plotly Express
        fig = px.line(df_grupo_contagem, x='ano_mes', y='Contagem', color='ORG_EXERCICIO',
                      markers=True, line_shape='linear',
                      title='Contagem de servidores nos 5 órgãos escolhidos ao longo dos mes e anos')
        
        # Ajustar configuração do eixo X para mostrar todos os anos
        fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))
        
        fig.update_layout(width=1000, height=750)
        
        # Exibir gráfico
        fig.show()




orgaos_escolhidos = [
    'Instituto Nacional do Seguro Social',
    'ministério da economia', 
    'Advocacia-Geral da União' ,     
    'Ministério da Ciência, Tecnologia, Inovações e Comunicações', 
    'Ministério da Saúde']

grafico_servidores_por_orgao_ano_mes(df, orgaos_escolhidos)

# %%
def dicionario_servidores_e_estagio_orgao_ano_mes (df_orgaos, orgaos_escolhidos):

    dicionario_orgaos = {}
    
    meses = df_orgaos['ano_mes'].unique()

    for mes in meses:
        
        for orgao in orgaos_escolhidos:

            qtd_regime_unico = df_orgaos[
                        df_orgaos["REGIME_JURIDICO"].str.contains("regime juridico unico", na=False, case=False) &
                        df_orgaos["ORG_EXERCICIO"].str.contains(orgao, na=False, case=False) &
                        (df_orgaos['ano_mes'] == mes)]["Contagem"].sum()

            qtd_estagiario =  df_orgaos[
                        df_orgaos["REGIME_JURIDICO"].str.contains("estag", na=False, case=False) &
                        df_orgaos["ORG_EXERCICIO"].str.contains(orgao, na=False, case=False) &
                        (df_orgaos['ano_mes'] == mes)]["Contagem"].sum()

            if not orgao in dicionario_orgaos:
                dicionario_orgaos[orgao] = {}

                        
            dicionario_orgaos[orgao][mes] = {'regime_unico': qtd_regime_unico,'estagiarios': qtd_estagiario,'indice_estagio': qtd_estagiario/qtd_regime_unico}
            

    display (dicionario_orgaos)




orgaos_escolhidos = [
    'Instituto Nacional do Seguro Social',
    'ministério da economia', 
    'Advocacia-Geral da União' ,     
    'Ministério da Ciência, Tecnologia, Inovações e Comunicações', 
    'Ministério da Saúde']

dicionario_servidores_e_estagio_orgao_ano_mes(df, orgaos_escolhidos)
# Out:
# {'Instituto Nacional do Seguro Social': {'2022-01': {'regime_unico': 2271,
#    'estagiarios': 1655,
#    'indice_estagio': 0.7287538529282255},
#   '2022-02': {'regime_unico': 2275,
#    'estagiarios': 1649,
#    'indice_estagio': 0.7248351648351649},
#   '2022-03': {'regime_unico': 2277,
#    'estagiarios': 1691,
#    'indice_estagio': 0.7426438296003514},
#   '2022-04': {'regime_unico': 2286,
#    'estagiarios': 1650,
#    'indice_estagio': 0.7217847769028871},
#   '2022-05': {'regime_unico': 2041,
#    'estagiarios': 1508,
#    'indice_estagio': 0.7388535031847133},
#   '2022-06': {'regime_unico': 2034,
#    'estagiarios': 1562,
#    'indice_estagio': 0.767944936086529},
#   '2022-07': {'regime_unico': 2036,
#    'estagiarios': 1584,
#    'indice_estagio': 0.7779960707269156},
#   '2022-08': {'regime_unico': 2031,
#    'estagiarios': 1604,
#    'indice_estagio': 0.7897587395371738},
#   '2022-09': {'regime_unico': 2028,
#    'estagiarios': 1630,
#    'indice_estagio': 0.8037475345167653},
#   '2022-10': {'regime_unico': 2085,
#    'estagiarios': 1658,
#    'indice_estagio': 0.7952038369304556},
#   '2022-11': {'regime_unico': 2085,
#    'estagiarios': 1656,
#    'indice_estagio': 0.7942446043165468},
#   '2022-12': {'regime_unico': 2077,
#    'estagiarios': 1665,
#    'indice_estagio': 0.8016369764082811},
#   '2021-01': {'regime_unico': 2272,
#    'estagiarios': 1147,
#    'indice_estagio': 0.5048415492957746},
#   '2021-02': {'regime_unico': 2271,
#    'estagiarios': 770,
#    'indice_estagio': 0.3390576838397182},
#   '2021-03': {'regime_unico': 2272,
#    'estagiarios': 1389,
#    'indice_estagio': 0.6113556338028169},
#   '2021-04': {'regime_unico': 2273,
#    'estagiarios': 1458,
#    'indice_estagio': 0.6414430268367796},
#   '2021-05': {'regime_unico': 2280,
#    'estagiarios': 1482,
#    'indice_estagio': 0.65},
#   '2021-06': {'regime_unico': 2276,
#    'estagiarios': 1537,
#    'indice_estagio': 0.6753075571177505},
#   '2021-07': {'regime_unico': 2281,
#    'estagiarios': 1570,
#    'indice_estagio': 0.6882946076282332},
#   '2021-08': {'regime_unico': 2288,
#    'estagiarios': 1616,
#    'indice_estagio': 0.7062937062937062},
#   '2021-09': {'regime_unico': 2278,
#    'estagiarios': 1651,
#    'indice_estagio': 0.7247585601404741},
#   '2021-10': {'regime_unico': 2291,
#    'estagiarios': 1673,
#    'indice_estagio': 0.7302487996508075},
#   '2021-11': {'regime_unico': 2285,
#    'estagiarios': 1701,
#    'indice_estagio': 0.7444201312910285},
#   '2021-12': {'regime_unico': 2270,
#    'estagiarios': 1727,
#    'indice_estagio': 0.7607929515418502},
#   '2023-01': {'regime_unico': 2074,
#    'estagiarios': 1607,
#    'indice_estagio': 0.7748312439729991},
#   '2023-02': {'regime_unico': 2074,
#    'estagiarios': 1583,
#    'indice_estagio': 0.7632594021215043},
#   '2023-03': {'regime_unico': 2069,
#    'estagiarios': 1584,
#    'indice_estagio': 0.7655872402126631},
#   '2023-04': {'regime_unico': 2062,
#    'estagiarios': 1600,
#    'indice_estagio': 0.7759456838021338},
#   '2023-05': {'regime_unico': 2063,
#    'estagiarios': 1616,
#    'indice_estagio': 0.7833252544837616},
#   '2023-06': {'regime_unico': 2065,
#    'estagiarios': 1621,
#    'indice_estagio': 0.7849878934624698},
#   '2023-07': {'regime_unico': 2060,
#    'estagiarios': 1611,
#    'indice_estagio': 0.7820388349514563},
#   '2023-08': {'regime_unico': 2059,
#    'estagiarios': 1623,
#    'indice_estagio': 0.7882467217095678},
#   '2023-09': {'regime_unico': 2067,
#    'estagiarios': 1634,
#    'indice_estagio': 0.7905176584421868},
#   '2023-10': {'regime_unico': 2061,
#    'estagiarios': 1633,
#    'indice_estagio': 0.7923338185346919},
#   '2023-11': {'regime_unico': 2063,
#    'estagiarios': 1635,
#    'indice_estagio': 0.7925351429956374}},
#  'ministério da economia': {'2022-01': {'regime_unico': 4569,
#    'estagiarios': 403,
#    'indice_estagio': 0.08820310790107244},
#   '2022-02': {'regime_unico': 4562,
#    'estagiarios': 396,
#    'indice_estagio': 0.08680403331871986},
#   '2022-03': {'regime_unico': 4556,
#    'estagiarios': 406,
#    'indice_estagio': 0.08911325724319578},
#   '2022-04': {'regime_unico': 4546,
#    'estagiarios': 407,
#    'indice_estagio': 0.08952925648922129},
#   '2022-05': {'regime_unico': 4675,
#    'estagiarios': 412,
#    'indice_estagio': 0.08812834224598931},
#   '2022-06': {'regime_unico': 4933,
#    'estagiarios': 435,
#    'indice_estagio': 0.08818163389418204},
#   '2022-07': {'regime_unico': 4143,
#    'estagiarios': 419,
#    'indice_estagio': 0.10113444363987449},
#   '2022-08': {'regime_unico': 3549,
#    'estagiarios': 434,
#    'indice_estagio': 0.1222879684418146},
#   '2022-09': {'regime_unico': 3558,
#    'estagiarios': 444,
#    'indice_estagio': 0.12478920741989882},
#   '2022-10': {'regime_unico': 3549,
#    'estagiarios': 456,
#    'indice_estagio': 0.12848689771766694},
#   '2022-11': {'regime_unico': 3551,
#    'estagiarios': 459,
#    'indice_estagio': 0.1292593635595607},
#   '2022-12': {'regime_unico': 3562,
#    'estagiarios': 452,
#    'indice_estagio': 0.12689500280741156},
#   '2021-01': {'regime_unico': 4569,
#    'estagiarios': 351,
#    'indice_estagio': 0.07682206172028891},
#   '2021-02': {'regime_unico': 4567,
#    'estagiarios': 353,
#    'indice_estagio': 0.077293628202321},
#   '2021-03': {'regime_unico': 4565,
#    'estagiarios': 360,
#    'indice_estagio': 0.07886089813800658},
#   '2021-04': {'regime_unico': 4565,
#    'estagiarios': 369,
#    'indice_estagio': 0.08083242059145673},
#   '2021-05': {'regime_unico': 4563,
#    'estagiarios': 377,
#    'indice_estagio': 0.08262108262108261},
#   '2021-06': {'regime_unico': 4567,
#    'estagiarios': 383,
#    'indice_estagio': 0.08386249178892052},
#   '2021-07': {'regime_unico': 4568,
#    'estagiarios': 365,
#    'indice_estagio': 0.07990367775831873},
#   '2021-08': {'regime_unico': 4586,
#    'estagiarios': 373,
#    'indice_estagio': 0.08133449629306586},
#   '2021-09': {'regime_unico': 4582,
#    'estagiarios': 385,
#    'indice_estagio': 0.0840244434744653},
#   '2021-10': {'regime_unico': 4586,
#    'estagiarios': 392,
#    'indice_estagio': 0.08547754034016572},
#   '2021-11': {'regime_unico': 4572,
#    'estagiarios': 396,
#    'indice_estagio': 0.08661417322834646},
#   '2021-12': {'regime_unico': 4579,
#    'estagiarios': 408,
#    'indice_estagio': 0.0891024241100677},
#   '2023-01': {'regime_unico': 3568,
#    'estagiarios': 447,
#    'indice_estagio': 0.12528026905829595},
#   '2023-02': {'regime_unico': 3751,
#    'estagiarios': 445,
#    'indice_estagio': 0.11863503065849107},
#   '2023-03': {'regime_unico': 3858,
#    'estagiarios': 437,
#    'indice_estagio': 0.11327112493519959},
#   '2023-04': {'regime_unico': 3868,
#    'estagiarios': 439,
#    'indice_estagio': 0.11349534643226473},
#   '2023-05': {'regime_unico': 3875,
#    'estagiarios': 456,
#    'indice_estagio': 0.1176774193548387},
#   '2023-06': {'regime_unico': 3805,
#    'estagiarios': 441,
#    'indice_estagio': 0.11590013140604467},
#   '2023-07': {'regime_unico': 3646,
#    'estagiarios': 437,
#    'indice_estagio': 0.11985737794843665},
#   '2023-08': {'regime_unico': 3111,
#    'estagiarios': 372,
#    'indice_estagio': 0.11957569913211186},
#   '2023-09': {'regime_unico': 2459,
#    'estagiarios': 16,
#    'indice_estagio': 0.0065067100447336315},
#   '2023-10': {'regime_unico': 24, 'estagiarios': 0, 'indice_estagio': 0.0},
#   '2023-11': {'regime_unico': 26,
#    'estagiarios': 2,
#    'indice_estagio': 0.07692307692307693}},
#  'Advocacia-Geral da União': {'2022-01': {'regime_unico': 694,
#    'estagiarios': 175,
#    'indice_estagio': 0.2521613832853026},
#   '2022-02': {'regime_unico': 692,
#    'estagiarios': 161,
#    'indice_estagio': 0.23265895953757226},
#   '2022-03': {'regime_unico': 690,
#    'estagiarios': 156,
#    'indice_estagio': 0.22608695652173913},
#   '2022-04': {'regime_unico': 761,
#    'estagiarios': 172,
#    'indice_estagio': 0.22601839684625494},
#   '2022-05': {'regime_unico': 790,
#    'estagiarios': 170,
#    'indice_estagio': 0.21518987341772153},
#   '2022-06': {'regime_unico': 845,
#    'estagiarios': 175,
#    'indice_estagio': 0.20710059171597633},
#   '2022-07': {'regime_unico': 854,
#    'estagiarios': 179,
#    'indice_estagio': 0.20960187353629978},
#   '2022-08': {'regime_unico': 866,
#    'estagiarios': 183,
#    'indice_estagio': 0.2113163972286374},
#   '2022-09': {'regime_unico': 916,
#    'estagiarios': 182,
#    'indice_estagio': 0.19868995633187772},
#   '2022-10': {'regime_unico': 931,
#    'estagiarios': 176,
#    'indice_estagio': 0.18904403866809882},
#   '2022-11': {'regime_unico': 941,
#    'estagiarios': 175,
#    'indice_estagio': 0.18597236981934112},
#   '2022-12': {'regime_unico': 954,
#    'estagiarios': 178,
#    'indice_estagio': 0.18658280922431866},
#   '2021-01': {'regime_unico': 576,
#    'estagiarios': 150,
#    'indice_estagio': 0.2604166666666667},
#   '2021-02': {'regime_unico': 581,
#    'estagiarios': 156,
#    'indice_estagio': 0.2685025817555938},
#   '2021-03': {'regime_unico': 583,
#    'estagiarios': 166,
#    'indice_estagio': 0.2847341337907376},
#   '2021-04': {'regime_unico': 577,
#    'estagiarios': 170,
#    'indice_estagio': 0.29462738301559793},
#   '2021-05': {'regime_unico': 640,
#    'estagiarios': 173,
#    'indice_estagio': 0.2703125},
#   '2021-06': {'regime_unico': 589,
#    'estagiarios': 179,
#    'indice_estagio': 0.30390492359932086},
#   '2021-07': {'regime_unico': 596,
#    'estagiarios': 177,
#    'indice_estagio': 0.29697986577181207},
#   '2021-08': {'regime_unico': 598,
#    'estagiarios': 174,
#    'indice_estagio': 0.2909698996655518},
#   '2021-09': {'regime_unico': 602,
#    'estagiarios': 181,
#    'indice_estagio': 0.30066445182724255},
#   '2021-10': {'regime_unico': 695,
#    'estagiarios': 184,
#    'indice_estagio': 0.2647482014388489},
#   '2021-11': {'regime_unico': 690,
#    'estagiarios': 187,
#    'indice_estagio': 0.2710144927536232},
#   '2021-12': {'regime_unico': 692,
#    'estagiarios': 185,
#    'indice_estagio': 0.26734104046242774},
#   '2023-01': {'regime_unico': 956,
#    'estagiarios': 172,
#    'indice_estagio': 0.1799163179916318},
#   '2023-02': {'regime_unico': 971,
#    'estagiarios': 170,
#    'indice_estagio': 0.17507723995880536},
#   '2023-03': {'regime_unico': 993,
#    'estagiarios': 175,
#    'indice_estagio': 0.17623363544813697},
#   '2023-04': {'regime_unico': 1008,
#    'estagiarios': 174,
#    'indice_estagio': 0.17261904761904762},
#   '2023-05': {'regime_unico': 1012,
#    'estagiarios': 166,
#    'indice_estagio': 0.16403162055335968},
#   '2023-06': {'regime_unico': 1033,
#    'estagiarios': 166,
#    'indice_estagio': 0.1606969990319458},
#   '2023-07': {'regime_unico': 1023,
#    'estagiarios': 165,
#    'indice_estagio': 0.16129032258064516},
#   '2023-08': {'regime_unico': 1039,
#    'estagiarios': 165,
#    'indice_estagio': 0.1588065447545717},
#   '2023-09': {'regime_unico': 1047,
#    'estagiarios': 164,
#    'indice_estagio': 0.15663801337153774},
#   '2023-10': {'regime_unico': 626,
#    'estagiarios': 16,
#    'indice_estagio': 0.025559105431309903},
#   '2023-11': {'regime_unico': 12,
#    'estagiarios': 1,
#    'indice_estagio': 0.08333333333333333}},
#  'Ministério da Ciência, Tecnologia, Inovações e Comunicações': {'2022-01': {'regime_unico': 482,
#    'estagiarios': 92,
#    'indice_estagio': 0.1908713692946058},
#   '2022-02': {'regime_unico': 481,
#    'estagiarios': 92,
#    'indice_estagio': 0.19126819126819128},
#   '2022-03': {'regime_unico': 479,
#    'estagiarios': 94,
#    'indice_estagio': 0.19624217118997914},
#   '2022-04': {'regime_unico': 481,
#    'estagiarios': 96,
#    'indice_estagio': 0.1995841995841996},
#   '2022-05': {'regime_unico': 483,
#    'estagiarios': 95,
#    'indice_estagio': 0.19668737060041408},
#   '2022-06': {'regime_unico': 482,
#    'estagiarios': 96,
#    'indice_estagio': 0.1991701244813278},
#   '2022-07': {'regime_unico': 481,
#    'estagiarios': 97,
#    'indice_estagio': 0.20166320166320167},
#   '2022-08': {'regime_unico': 481,
#    'estagiarios': 104,
#    'indice_estagio': 0.21621621621621623},
#   '2022-09': {'regime_unico': 481,
#    'estagiarios': 101,
#    'indice_estagio': 0.20997920997921},
#   '2022-10': {'regime_unico': 480,
#    'estagiarios': 102,
#    'indice_estagio': 0.2125},
#   '2022-11': {'regime_unico': 481,
#    'estagiarios': 109,
#    'indice_estagio': 0.22661122661122662},
#   '2022-12': {'regime_unico': 484,
#    'estagiarios': 117,
#    'indice_estagio': 0.24173553719008264},
#   '2021-01': {'regime_unico': 667,
#    'estagiarios': 44,
#    'indice_estagio': 0.06596701649175413},
#   '2021-02': {'regime_unico': 660,
#    'estagiarios': 50,
#    'indice_estagio': 0.07575757575757576},
#   '2021-03': {'regime_unico': 662,
#    'estagiarios': 66,
#    'indice_estagio': 0.09969788519637462},
#   '2021-04': {'regime_unico': 667,
#    'estagiarios': 69,
#    'indice_estagio': 0.10344827586206896},
#   '2021-05': {'regime_unico': 666,
#    'estagiarios': 55,
#    'indice_estagio': 0.08258258258258258},
#   '2021-06': {'regime_unico': 665,
#    'estagiarios': 58,
#    'indice_estagio': 0.08721804511278196},
#   '2021-07': {'regime_unico': 664,
#    'estagiarios': 61,
#    'indice_estagio': 0.09186746987951808},
#   '2021-08': {'regime_unico': 512,
#    'estagiarios': 65,
#    'indice_estagio': 0.126953125},
#   '2021-09': {'regime_unico': 485,
#    'estagiarios': 76,
#    'indice_estagio': 0.15670103092783505},
#   '2021-10': {'regime_unico': 485,
#    'estagiarios': 77,
#    'indice_estagio': 0.15876288659793814},
#   '2021-11': {'regime_unico': 485,
#    'estagiarios': 84,
#    'indice_estagio': 0.1731958762886598},
#   '2021-12': {'regime_unico': 483,
#    'estagiarios': 95,
#    'indice_estagio': 0.19668737060041408},
#   '2023-01': {'regime_unico': 507,
#    'estagiarios': 111,
#    'indice_estagio': 0.21893491124260356},
#   '2023-02': {'regime_unico': 504,
#    'estagiarios': 104,
#    'indice_estagio': 0.20634920634920634},
#   '2023-03': {'regime_unico': 493,
#    'estagiarios': 108,
#    'indice_estagio': 0.21906693711967545},
#   '2023-04': {'regime_unico': 484,
#    'estagiarios': 108,
#    'indice_estagio': 0.2231404958677686},
#   '2023-05': {'regime_unico': 473,
#    'estagiarios': 107,
#    'indice_estagio': 0.226215644820296},
#   '2023-06': {'regime_unico': 477,
#    'estagiarios': 101,
#    'indice_estagio': 0.21174004192872117},
#   '2023-07': {'regime_unico': 476,
#    'estagiarios': 102,
#    'indice_estagio': 0.21428571428571427},
#   '2023-08': {'regime_unico': 482,
#    'estagiarios': 103,
#    'indice_estagio': 0.21369294605809128},
#   '2023-09': {'regime_unico': 483,
#    'estagiarios': 101,
#    'indice_estagio': 0.20910973084886128},
#   '2023-10': {'regime_unico': 485,
#    'estagiarios': 106,
#    'indice_estagio': 0.21855670103092784},
#   '2023-11': {'regime_unico': 478,
#    'estagiarios': 107,
#    'indice_estagio': 0.22384937238493724}},
#  'Ministério da Saúde': {'2022-01': {'regime_unico': 1040,
#    'estagiarios': 92,
#    'indice_estagio': 0.08846153846153847},
#   '2022-02': {'regime_unico': 1037,
#    'estagiarios': 103,
#    'indice_estagio': 0.09932497589199614},
#   '2022-03': {'regime_unico': 1056,
#    'estagiarios': 101,
#    'indice_estagio': 0.09564393939393939},
#   '2022-04': {'regime_unico': 1067,
#    'estagiarios': 96,
#    'indice_estagio': 0.08997188378631678},
#   '2022-05': {'regime_unico': 1060,
#    'estagiarios': 99,
#    'indice_estagio': 0.09339622641509433},
#   '2022-06': {'regime_unico': 1051,
#    'estagiarios': 102,
#    'indice_estagio': 0.09705042816365367},
#   '2022-07': {'regime_unico': 1063,
#    'estagiarios': 105,
#    'indice_estagio': 0.09877704609595485},
#   '2022-08': {'regime_unico': 1227,
#    'estagiarios': 104,
#    'indice_estagio': 0.08475957620211899},
#   '2022-09': {'regime_unico': 1196,
#    'estagiarios': 98,
#    'indice_estagio': 0.08193979933110368},
#   '2022-10': {'regime_unico': 1161,
#    'estagiarios': 104,
#    'indice_estagio': 0.08957795004306632},
#   '2022-11': {'regime_unico': 1155,
#    'estagiarios': 102,
#    'indice_estagio': 0.08831168831168831},
#   '2022-12': {'regime_unico': 1146,
#    'estagiarios': 105,
#    'indice_estagio': 0.09162303664921466},
#   '2021-01': {'regime_unico': 1006,
#    'estagiarios': 57,
#    'indice_estagio': 0.05666003976143141},
#   '2021-02': {'regime_unico': 1005,
#    'estagiarios': 60,
#    'indice_estagio': 0.05970149253731343},
#   '2021-03': {'regime_unico': 1007,
#    'estagiarios': 61,
#    'indice_estagio': 0.0605759682224429},
#   '2021-04': {'regime_unico': 1013,
#    'estagiarios': 69,
#    'indice_estagio': 0.06811451135241856},
#   '2021-05': {'regime_unico': 1018,
#    'estagiarios': 70,
#    'indice_estagio': 0.068762278978389},
#   '2021-06': {'regime_unico': 1034,
#    'estagiarios': 76,
#    'indice_estagio': 0.0735009671179884},
#   '2021-07': {'regime_unico': 1038,
#    'estagiarios': 79,
#    'indice_estagio': 0.07610789980732177},
#   '2021-08': {'regime_unico': 1041,
#    'estagiarios': 81,
#    'indice_estagio': 0.07780979827089338},
#   '2021-09': {'regime_unico': 1040,
#    'estagiarios': 91,
#    'indice_estagio': 0.0875},
#   '2021-10': {'regime_unico': 1037,
#    'estagiarios': 92,
#    'indice_estagio': 0.08871745419479267},
#   '2021-11': {'regime_unico': 1039,
#    'estagiarios': 93,
#    'indice_estagio': 0.08950914340712224},
#   '2021-12': {'regime_unico': 1036,
#    'estagiarios': 100,
#    'indice_estagio': 0.09652509652509653},
#   '2023-01': {'regime_unico': 1145,
#    'estagiarios': 89,
#    'indice_estagio': 0.0777292576419214},
#   '2023-02': {'regime_unico': 1160,
#    'estagiarios': 92,
#    'indice_estagio': 0.07931034482758621},
#   '2023-03': {'regime_unico': 1134,
#    'estagiarios': 89,
#    'indice_estagio': 0.07848324514991181},
#   '2023-04': {'regime_unico': 1141,
#    'estagiarios': 90,
#    'indice_estagio': 0.07887817703768624},
#   '2023-05': {'regime_unico': 1136,
#    'estagiarios': 95,
#    'indice_estagio': 0.08362676056338028},
#   '2023-06': {'regime_unico': 1129,
#    'estagiarios': 98,
#    'indice_estagio': 0.08680248007085917},
#   '2023-07': {'regime_unico': 1122,
#    'estagiarios': 97,
#    'indice_estagio': 0.08645276292335116},
#   '2023-08': {'regime_unico': 1114,
#    'estagiarios': 100,
#    'indice_estagio': 0.08976660682226212},
#   '2023-09': {'regime_unico': 1117,
#    'estagiarios': 101,
#    'indice_estagio': 0.09042076991942703},
#   '2023-10': {'regime_unico': 1115,
#    'estagiarios': 99,
#    'indice_estagio': 0.08878923766816144},
#   '2023-11': {'regime_unico': 1113,
#    'estagiarios': 101,
#    'indice_estagio': 0.09074573225516622}}}

# %%
df_janeiro[df_janeiro["REGIME_JURIDICO"].str.contains("estag", na=False, case=False) ].value_counts("ORG_EXERCICIO")

# %%
orgaos = ['minis']

df_filtrado = df_janeiro[
                        df_janeiro["REGIME_JURIDICO"].str.contains("regime juridico unico", na=False, case=False) &
                        df_janeiro["ORG_EXERCICIO"].str.contains('|'.join(orgaos), na=False, case=False)
                    ]

display(df_filtrado['ORG_EXERCICIO'].unique())

# %% [markdown]
# # Contagem de servidores nos 5 órgãos escolhidos ao longo dos anos

# %%
# Filtrar apenas os registros onde 'REGIME JURIDICO UNICO' está presente na coluna 'REGIME_JURIDICO'
df_servidores = df[df['REGIME_JURIDICO'].str.lower().str.contains('regime juridico unico', case=False, na=False)]

# Lista de palavras-chave para filtrar as empresas
palavras_chave_empresas = ['economia', 'fazenda', 'educação', 'saúde', 'pres']

mes_selecionado = 1

# Filtrar DataFrame para incluir apenas empresas que contenham as palavras-chave
df_orgaos_selecionados = df_servidores[df_servidores['ORGSUP_EXERCICIO'].str.lower().str.contains('|'.join(palavras_chave_empresas), case=False, na=False) &
                                        df_]

# Agrupar e contar por empresa, regime jurídico e ano
df_contagem_combinacoes = df_orgaos_selecionados.groupby(['ORGSUP_EXERCICIO', 'REGIME_JURIDICO', 'ano'])['Contagem'].mean().reset_index()

# Criar gráfico interativo de linha usando o Plotly Express
fig = px.line(df_contagem_combinacoes, x='ano', y='Contagem', color='ORGSUP_EXERCICIO',
              markers=True, line_shape='linear',
              title='Contagem de servidores nos 5 órgãos escolhidos ao longo dos anos')

# Ajustar configuração do eixo X para mostrar todos os anos
fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))

fig.update_layout(width=1000, height=750)

# Exibir gráfico
fig.show()

# %% [markdown]
# # Contagem de estagiários em todos os órgãos ao longo dos anos

# %%
# Filtrar apenas os registros onde 'ESTAGIO' está presente na coluna 'REGIME_JURIDICO'
df_estagio = df[df['REGIME_JURIDICO'].str.lower().str.contains('est', case=False, na=False)]

df_contagem_combinacoes = df_estagio.groupby(['ORGSUP_EXERCICIO','REGIME_JURIDICO', 'ano'])['Contagem'].mean().reset_index()

# Agrupe pelo REGIME_JURIDICO e ordene dentro de cada grupo pela coluna ESTAGIO
df_agrupado_ordenado = df_contagem_combinacoes.sort_values(by=['ORGSUP_EXERCICIO', 'REGIME_JURIDICO', 'ano'])

'''display(df_agrupado_ordenado.head(10))'''

# Criar gráfico interativo de linha usando o Plotly Express
fig = px.line(df_agrupado_ordenado, x='ano', y='Contagem', color='ORGSUP_EXERCICIO', markers=True, line_shape='linear',
              title='Contagem de estagiários em todos os órgãos ao longo dos anos')

# Ajustar configuração do eixo X para mostrar todos os anos
fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))

fig.update_layout(width=1000, height=750)

# Exibir gráfico
fig.show()

# %% [markdown]
# # Contagem de estagiários nos 5 órgãos escolhidos ao longo dos anos

# %%
def grafico_servidores_por_orgao_e_ano (df_orgaos, orgaos_superiores_escolhidos):

    df_filtrado = df_orgaos[
                        df_orgaos["REGIME_JURIDICO"].str.contains("estagio", na=False, case=False) &
                        df_orgaos["ORGSUP_EXERCICIO"].str.contains('|'.join(orgaos_superiores_escolhidos), na=False, case=False)
                    ]
    
    # Supondo que df seja o seu DataFrame    
    tamanho = df_filtrado['REGIME_JURIDICO'].count()
    
    if tamanho == 0:
        
        display(f'O dataframe não tem registros')

    else:
        df_grupo_contagem = df_filtrado.groupby(['ORGSUP_EXERCICIO','ano'])['Contagem'].sum().reset_index()

        # Criar gráfico interativo de linha usando o Plotly Express
        fig = px.line(df_grupo_contagem, x='ano', y='Contagem', color='ORG_EXERCICIO',
                      markers=True, line_shape='linear',
                      title='Contagem de estagiários nos 5 órgãos escolhidos ao longo dos anos')
        
        # Ajustar configuração do eixo X para mostrar todos os anos
        fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))
        
        fig.update_layout(width=1000, height=750)
        
        # Exibir gráfico
        fig.show()

orgaos_superiores_escolhidos = ['economia', 'fazenda', 'educação', 'saúde', 'pres', 'sem']

grafico_servidores_por_orgao_e_ano(df_janeiro, orgaos_superiores_escolhidos)

# %%
# Filtrar apenas os registros onde 'ESTAGIO' está presente na coluna 'REGIME_JURIDICO'
df_estagio = df[df['REGIME_JURIDICO'].str.lower().str.contains('est', case=False, na=False)]

# Lista de palavras-chave para filtrar as empresas
palavras_chave_empresas = ['economia', 'fazenda', 'educação', 'saúde', 'pres']

# Filtrar DataFrame para incluir apenas empresas que contenham as palavras-chave
df_orgaos_selecionados = df_estagio[df_estagio['ORGSUP_EXERCICIO'].str.lower().str.contains('|'.join(palavras_chave_empresas), case=False, na=False)]

# Agrupar e contar por empresa, regime jurídico e ano
df_contagem_combinacoes = df_orgaos_selecionados.groupby(['ORGSUP_EXERCICIO', 'REGIME_JURIDICO', 'ano_mes'])['Contagem'].sum().reset_index()

# Criar gráfico interativo de linha usando o Plotly Express
fig = px.line(df_contagem_combinacoes, x='ano_mes', y='Contagem', color='ORGSUP_EXERCICIO',
              markers=True, line_shape='linear',
              title='Contagem de estagiários nos 5 órgãos escolhidos ao longo dos anos')

# Ajustar configuração do eixo X para mostrar todos os anos
fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))

fig.update_layout(width=1000, height=750)

# Exibir gráfico
fig.show()

# %%
# Filtrar apenas os registros onde 'ESTAGIO' está presente na coluna 'REGIME_JURIDICO'
df_estagio = df[df['REGIME_JURIDICO'].str.lower().str.contains('est', case=False, na=False)]

# Filtrar apenas os registros onde 'REGIME JURIDICO UNICO' está presente na coluna 'REGIME_JURIDICO'
df_servidores = df[df['REGIME_JURIDICO'].str.lower().str.contains('regime juridico unico', case=False, na=False)]

# Lista de palavras-chave para filtrar as empresas
palavras_chave_empresas = ['economia', 'fazenda', 'educação', 'saúde', 'pres']

# Filtrar DataFrame para incluir apenas empresas que contenham as palavras-chave
df_orgaos_selecionados_estagio = df_estagio[df_estagio['ORGSUP_EXERCICIO'].str.lower().str.contains('|'.join(palavras_chave_empresas), case=False, na=False)]
df_orgaos_selecionados_servidores = df_servidores[df_servidores['ORGSUP_EXERCICIO'].str.lower().str.contains('|'.join(palavras_chave_empresas), case=False, na=False)]

# Agrupar e contar por ano para estagiários
df_contagem_estagio = df_orgaos_selecionados_estagio.groupby(['ano']).mean().reset_index(name='Contagem_Estagio')

# Agrupar e contar por ano para servidores
df_contagem_servidores = df_orgaos_selecionados_servidores.groupby(['ano']).mean().reset_index(name='Contagem_Servidores')

# Mesclar os DataFrames de estagiários e servidores
df_contagem_total = pd.merge(df_contagem_estagio, df_contagem_servidores, on='ano', how='outer').fillna(0)

# Criar gráfico de barras usando o Plotly Express
fig = px.bar(df_contagem_total, x='ano', y=['Contagem_Estagio', 'Contagem_Servidores'],
             labels={'value': 'Quantidade', 'variable': 'Tipo'},
             title='Comparação da Quantidade Total de Estagiários e Servidores nos 5 órgãos escolhidos ao longo dos anos',
             color_discrete_sequence=['blue', 'orange'])

# Ajustar configuração do eixo X para mostrar todos os anos
fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))

fig.update_layout(width=1000, height=750)

# Exibir gráfico
fig.show()

# %% [markdown]
# # Comparação servidores X estagiários nos 5 órgãos escolhidos ao longo dos anos

# %%
# Filtrar apenas os registros onde 'ESTAGIO' está presente na coluna 'REGIME_JURIDICO'
df_estagio = df[df['REGIME_JURIDICO'].str.lower().str.contains('est', case=False, na=False)]

# Filtrar apenas os registros onde 'REGIME JURIDICO UNICO' está presente na coluna 'REGIME_JURIDICO'
df_servidores = df[df['REGIME_JURIDICO'].str.lower().str.contains('regime juridico unico', case=False, na=False)]

# Lista de palavras-chave para filtrar as empresas
palavras_chave_empresas = ['economia', 'fazenda', 'educação', 'saúde', 'pres']

# Filtrar DataFrame para incluir apenas empresas que contenham as palavras-chave
df_orgaos_selecionados_estagio = df_estagio[df_estagio['ORGSUP_EXERCICIO'].str.lower().str.contains('|'.join(palavras_chave_empresas), case=False, na=False)]
df_orgaos_selecionados_servidores = df_servidores[df_servidores['ORGSUP_EXERCICIO'].str.lower().str.contains('|'.join(palavras_chave_empresas), case=False, na=False)]

# Contar a frequência por ano, empresa e tipo (estagiário ou servidor)
df_contagem_estagio = df_orgaos_selecionados_estagio.groupby(['ano', 'ORGSUP_EXERCICIO']).size().reset_index(name='Contagem_Estagio')
df_contagem_servidores = df_orgaos_selecionados_servidores.groupby(['ano', 'ORGSUP_EXERCICIO']).size().reset_index(name='Contagem_Servidores')

# Mesclar os DataFrames de estagiários e servidores
df_contagem_total = pd.merge(df_contagem_estagio, df_contagem_servidores, on=['ano', 'ORGSUP_EXERCICIO'], how='outer').fillna(0)

# Criar gráfico de barras agrupadas usando o Plotly Express
fig = px.bar(df_contagem_total, x='ano', y=['Contagem_Estagio', 'Contagem_Servidores'],
             color='ORGSUP_EXERCICIO', barmode='group',
             labels={'value': 'Quantidade', 'variable': 'Tipo'},
             title='Comparação da Quantidade Total de Estagiários e Servidores nos 5 órgãos escolhidos ao longo dos anos',
             color_discrete_sequence=px.colors.qualitative.Set1)

fig.update_layout(width=1000, height=750)

# Exibir gráfico
fig.show()
