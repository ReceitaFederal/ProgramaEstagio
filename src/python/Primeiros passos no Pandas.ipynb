# %%
import pandas as pd

# %%
caminho_arquivo = "/home/carolcardoso/Downloads/202311_Cadastro.csv"

df_cadastro = pd.read_csv(caminho_arquivo, encoding="iso-8859-1", sep=';')
# Out:
# /tmp/ipykernel_5599/2122720666.py:3: DtypeWarning: Columns (2,5,7,9,34,36,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cadastro = pd.read_csv(caminho_arquivo, encoding="iso-8859-1", sep=';')

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)

# %%
display(df_cadastro)
# Out:
#         Id_SERVIDOR_PORTAL                            NOME             CPF  \
# 0                310606473      AARAO CARLOS LUZ MACAMBIRA  ***.017.623-**
# 1                313006968        AARAO FERREIRA LIMA NETO  ***.116.132-**
# 2                313006968        AARAO FERREIRA LIMA NETO  ***.116.132-**
# 3                311039523              AARAO MEIR SERRUYA  ***.693.832-**
# 4                310150191  AARAO PEREIRA DE ARAUJO JUNIOR  ***.031.184-**
# ...                    ...                             ...             ...
# 748591                 -11                        Sigiloso             NaN
# 748592                 -11                        Sigiloso             NaN
# 748593                 -11                        Sigiloso             NaN
# 748594                 -11                        Sigiloso             NaN
# 748595                 -11                        Sigiloso             NaN
#
#        MATRICULA                        DESCRICAO_CARGO CLASSE_CARGO  \
# 0        016****           BIBLIOTECARIO-DOCUMENTALISTA            E
# 1        014****                           Sem informaç          NaN
# 2        014****       PROFESSOR DO MAGISTERIO SUPERIOR            7
# 3        033****                   FISIOTERAPEUTA - 30H            S
# 4        002****  PROFESSOR ENS BASICO TECN TECNOLOGICO            D
# ...          ...                                    ...          ...
# 748591   001****                               Sigiloso          NaN
# 748592   001****                               Sigiloso          NaN
# 748593   001****                               Sigiloso          NaN
# 748594   001****                               Sigiloso          NaN
# 748595   001****                               Sigiloso          NaN
#
#         REFERENCIA_CARGO PADRAO_CARGO  NIVEL_CARGO SIGLA_FUNCAO  NIVEL_FUNCAO  \
# 0                    0.0          410          0.0           -1            -1
# 1                   -1.0           -1         -1.0           FG             1
# 2                    0.0          NaN        702.0           -1            -1
# 3                    0.0          NaN        201.0           -1            -1
# 4                    0.0          NaN        501.0           -1            -1
# ...                  ...          ...          ...          ...           ...
# 748591               NaN          NaN          NaN          -11           -11
# 748592               NaN          NaN          NaN          -11           -11
# 748593               NaN          NaN          NaN          -11           -11
# 748594               NaN          NaN          NaN          -11           -11
# 748595               NaN          NaN          NaN          -11           -11
#
#                            FUNCAO  CODIGO_ATIVIDADE     ATIVIDADE  \
# 0                  Sem informação                -1  Sem informaç
# 1       FUNCAO GRATIFICADA - IFES                99    DIRETOR(A)
# 2                  Sem informação                -1  Sem informaç
# 3                  Sem informação                -1  Sem informaç
# 4                  Sem informação                -1  Sem informaç
# ...                           ...               ...           ...
# 748591                   Sigiloso               -11      Sigiloso
# 748592                   Sigiloso               -11      Sigiloso
# 748593                   Sigiloso               -11      Sigiloso
# 748594                   Sigiloso               -11      Sigiloso
# 748595                   Sigiloso               -11      Sigiloso
#
#        OPCAO_PARCIAL  COD_UORG_LOTACAO  \
# 0                NaN    26405000000040
# 1                NaN    26239000001515
# 2                NaN    26239000001515
# 3                NaN    26443035000000
# 4                NaN    26417000000013
# ...              ...               ...
# 748591             N               -11
# 748592             N               -11
# 748593             N               -11
# 748594             N               -11
# 748595             N               -11
#
#                                     UORG_LOTACAO  COD_ORG_LOTACAO  \
# 0                  DIRETORIA GERAL/CAMPUS SOBRAL            26405
# 1       NUCLEO DE DESENV AMAZONICO EM ENGENHARIA            26239
# 2       NUCLEO DE DESENV AMAZONICO EM ENGENHARIA            26239
# 3                    COMPLEXO HOSPITALAR DA UFPA            26443
# 4                 DIR. DESENVOLVIMENTO ENSINO-JP            26417
# ...                                          ...              ...
# 748591                                  Sigiloso            30802
# 748592                                  Sigiloso            30802
# 748593                                  Sigiloso            30802
# 748594                                  Sigiloso            30802
# 748595                                  Sigiloso            30802
#
#                                         ORG_LOTACAO  COD_ORGSUP_LOTACAO  \
# 0                        Instituto Federal do Ceará               15000
# 1                      Universidade Federal do Pará               15000
# 2                      Universidade Federal do Pará               15000
# 3       Empresa Brasileira de Serviços Hospitalares               15000
# 4                      Instituto Federal da Paraíba               15000
# ...                                             ...                 ...
# 748591   Departamento de Polícia Rodoviária Federal               20000
# 748592   Departamento de Polícia Rodoviária Federal               20000
# 748593   Departamento de Polícia Rodoviária Federal               20000
# 748594   Departamento de Polícia Rodoviária Federal               20000
# 748595   Departamento de Polícia Rodoviária Federal               20000
#
#                                    ORGSUP_LOTACAO  COD_UORG_EXERCICIO  \
# 0                          Ministério da Educação      26405000000717
# 1                          Ministério da Educação      26239000001515
# 2                          Ministério da Educação      26239000001515
# 3                          Ministério da Educação                  -3
# 4                          Ministério da Educação      26417000000240
# ...                                           ...                 ...
# 748591  Ministério da Justiça e Segurança Pública                 -11
# 748592  Ministério da Justiça e Segurança Pública                 -11
# 748593  Ministério da Justiça e Segurança Pública                 -11
# 748594  Ministério da Justiça e Segurança Pública                 -11
# 748595  Ministério da Justiça e Segurança Pública                 -11
#
#                                   UORG_EXERCICIO  COD_ORG_EXERCICIO  \
# 0                        DIRETORIA DE ENSINO-SOB              26405
# 1       NUCLEO DE DESENV AMAZONICO EM ENGENHARIA              26239
# 2       NUCLEO DE DESENV AMAZONICO EM ENGENHARIA              26239
# 3                                       Inválido              26443
# 4               UNID. ACAD. I DES, ESTR.M.AMB-JP              26417
# ...                                          ...                ...
# 748591                                  Sigiloso              30802
# 748592                                  Sigiloso              30802
# 748593                                  Sigiloso              30802
# 748594                                  Sigiloso              30802
# 748595                                  Sigiloso              30802
#
#                                       ORG_EXERCICIO  COD_ORGSUP_EXERCICIO  \
# 0                        Instituto Federal do Ceará                 15000
# 1                      Universidade Federal do Pará                 15000
# 2                      Universidade Federal do Pará                 15000
# 3       Empresa Brasileira de Serviços Hospitalares                 15000
# 4                      Instituto Federal da Paraíba                 15000
# ...                                             ...                   ...
# 748591   Departamento de Polícia Rodoviária Federal                 20000
# 748592   Departamento de Polícia Rodoviária Federal                 20000
# 748593   Departamento de Polícia Rodoviária Federal                 20000
# 748594   Departamento de Polícia Rodoviária Federal                 20000
# 748595   Departamento de Polícia Rodoviária Federal                 20000
#
#                                  ORGSUP_EXERCICIO  COD_TIPO_VINCULO  \
# 0                          Ministério da Educação                 2
# 1                          Ministério da Educação                 1
# 2                          Ministério da Educação                 2
# 3                          Ministério da Educação                 2
# 4                          Ministério da Educação                 2
# ...                                           ...               ...
# 748591  Ministério da Justiça e Segurança Pública                 2
# 748592  Ministério da Justiça e Segurança Pública                 2
# 748593  Ministério da Justiça e Segurança Pública                 2
# 748594  Ministério da Justiça e Segurança Pública                 2
# 748595  Ministério da Justiça e Segurança Pública                 2
#
#        TIPO_VINCULO     SITUACAO_VINCULO  DATA_INICIO_AFASTAMENTO  \
# 0             Cargo     ATIVO PERMANENTE                      NaN
# 1            Função     ATIVO PERMANENTE                      NaN
# 2             Cargo     ATIVO PERMANENTE                      NaN
# 3             Cargo  CELETISTA/EMPREGADO                      NaN
# 4             Cargo     ATIVO PERMANENTE                      NaN
# ...             ...                  ...                      ...
# 748591        Cargo             Sigiloso                      NaN
# 748592        Cargo             Sigiloso                      NaN
# 748593        Cargo             Sigiloso                      NaN
# 748594        Cargo             Sigiloso                      NaN
# 748595        Cargo             Sigiloso                      NaN
#
#         DATA_TERMINO_AFASTAMENTO                    REGIME_JURIDICO  \
# 0                            NaN              REGIME JURIDICO UNICO
# 1                            NaN              REGIME JURIDICO UNICO
# 2                            NaN              REGIME JURIDICO UNICO
# 3                            NaN  CONSOLIDACAO DAS LEIS DO TRABALHO
# 4                            NaN              REGIME JURIDICO UNICO
# ...                          ...                                ...
# 748591                       NaN                       Sem informaç
# 748592                       NaN                       Sem informaç
# 748593                       NaN                       Sem informaç
# 748594                       NaN                       Sem informaç
# 748595                       NaN                       Sem informaç
#
#         JORNADA_DE_TRABALHO DATA_INGRESSO_CARGOFUNCAO  \
# 0         40 HORAS SEMANAIS                11/02/2009
# 1       DEDICACAO EXCLUSIVA                16/03/2020
# 2       DEDICACAO EXCLUSIVA                01/03/2013
# 3         30 HORAS SEMANAIS                07/12/2022
# 4       DEDICACAO EXCLUSIVA                01/03/2013
# ...                     ...                       ...
# 748591         Sem informaç                       NaN
# 748592         Sem informaç                       NaN
# 748593         Sem informaç                       NaN
# 748594         Sem informaç                       NaN
# 748595         Sem informaç                       NaN
#
#         DATA_NOMEACAO_CARGOFUNCAO DATA_INGRESSO_ORGAO  \
# 0                             NaN          29/12/2008
# 1                             NaN          24/07/2006
# 2                             NaN          24/07/2006
# 3                             NaN          07/12/2022
# 4                             NaN          29/12/2008
# ...                           ...                 ...
# 748591                        NaN                 NaN
# 748592                        NaN                 NaN
# 748593                        NaN                 NaN
# 748594                        NaN                 NaN
# 748595                        NaN                 NaN
#
#        DOCUMENTO_INGRESSO_SERVICOPUBLICO DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO  \
# 0                                    699                           11/02/2009
# 1                                   2475                           16/08/2006
# 2                                   2475                           16/08/2006
# 3                                    NaN                                  NaN
# 4                              000000124                           03/05/1993
# ...                                  ...                                  ...
# 748591                               NaN                                  NaN
# 748592                               NaN                                  NaN
# 748593                               NaN                                  NaN
# 748594                               NaN                                  NaN
# 748595                               NaN                                  NaN
#
#         DIPLOMA_INGRESSO_CARGOFUNCAO DIPLOMA_INGRESSO_ORGAO  \
# 0                                NaN                    LEI
# 1                                NaN               PORTARIA
# 2                                NaN               PORTARIA
# 3                                NaN               CONTRATO
# 4                                NaN                    LEI
# ...                              ...                    ...
# 748591                           NaN           Sem informaç
# 748592                           NaN           Sem informaç
# 748593                           NaN           Sem informaç
# 748594                           NaN           Sem informaç
# 748595                           NaN           Sem informaç
#
#        DIPLOMA_INGRESSO_SERVICOPUBLICO  UF_EXERCICIO
# 0                             PORTARIA            -1
# 1                             PORTARIA            -1
# 2                             PORTARIA            -1
# 3                             Inválido            -1
# 4                             PORTARIA            -1
# ...                                ...           ...
# 748591                    Sem informaç            -1
# 748592                    Sem informaç            -1
# 748593                    Sem informaç            -1
# 748594                    Sem informaç            -1
# 748595                    Sem informaç            -1
#
# [748596 rows x 43 columns]

# %%
df_filtro = df_cadastro[df_cadastro["REGIME_JURIDICO"].str.contains("estag", case=False, na=False)]

display(df_filtro)
# Out:
#         Id_SERVIDOR_PORTAL                            NOME             CPF  \
# 9                313302667             AARON MATHEUS MOURA  ***.470.823-**
# 76               310822592      ABDON BANDEIRA ANDRE FILHO  ***.884.724-**
# 144              312093404          ABEL DE AZEVEDO GARCIA  ***.240.960-**
# 168              311925156          ABEL ISACK DA SILVA SA  ***.982.643-**
# 262              310762883         ABGAIL PEREIRA DE SOUSA  ***.063.693-**
# ...                    ...                             ...             ...
# 710973           312767171        ZELIA BARRETO DOS SANTOS  ***.514.288-**
# 711408           311272146            ZIDANE BORGES VIEIRA  ***.748.355-**
# 711457           313038984  ZILDA CARDOSO ABBADIA ABHULIME  ***.102.196-**
# 711526           311974312   ZILDA VITORIA DE SOUSA AMORIM  ***.667.933-**
# 711727           310816647              ZOE MUNDABA NTUMBA  ***.524.611-**
#
#        MATRICULA DESCRICAO_CARGO CLASSE_CARGO  REFERENCIA_CARGO PADRAO_CARGO  \
# 9        033****        Inválido          NaN               0.0          NaN
# 76       033****        Inválido          NaN               0.0          NaN
# 144      033****        Inválido          NaN               0.0          NaN
# 168      032****        Inválido          NaN               0.0          NaN
# 262      032****        Inválido          NaN               0.0          NaN
# ...          ...             ...          ...               ...          ...
# 710973   033****        Inválido          NaN               0.0          NaN
# 711408   033****        Inválido          NaN               0.0          NaN
# 711457   033****        Inválido          NaN               0.0          NaN
# 711526   033****        Inválido          NaN               0.0          NaN
# 711727   033****        Inválido          NaN               0.0          NaN
#
#         NIVEL_CARGO SIGLA_FUNCAO  NIVEL_FUNCAO          FUNCAO  \
# 9               0.0           -1            -1  Sem informação
# 76              0.0           -1            -1  Sem informação
# 144             0.0           -1            -1  Sem informação
# 168             0.0           -1            -1  Sem informação
# 262             0.0           -1            -1  Sem informação
# ...             ...          ...           ...             ...
# 710973          0.0           -1            -1  Sem informação
# 711408          0.0           -1            -1  Sem informação
# 711457          0.0           -1            -1  Sem informação
# 711526          0.0           -1            -1  Sem informação
# 711727          0.0           -1            -1  Sem informação
#
#         CODIGO_ATIVIDADE     ATIVIDADE OPCAO_PARCIAL  COD_UORG_LOTACAO  \
# 9                     -1  Sem informaç           NaN                -3
# 76                    -1  Sem informaç           NaN                -3
# 144                   -1  Sem informaç           NaN                -3
# 168                   -1  Sem informaç           NaN                -3
# 262                   -1  Sem informaç           NaN                -3
# ...                  ...           ...           ...               ...
# 710973                -1  Sem informaç           NaN                -3
# 711408                -1  Sem informaç           NaN                -3
# 711457                -1  Sem informaç           NaN                -3
# 711526                -1  Sem informaç           NaN                -3
# 711727                -1  Sem informaç           NaN                -3
#
#        UORG_LOTACAO  COD_ORG_LOTACAO  \
# 9          Inválido            17600
# 76         Inválido            26240
# 144        Inválido            26436
# 168        Inválido            26271
# 262        Inválido            57202
# ...             ...              ...
# 710973     Inválido            57202
# 711408     Inválido            26232
# 711457     Inválido            39251
# 711526     Inválido            57202
# 711727     Inválido            26258
#
#                                         ORG_LOTACAO  COD_ORGSUP_LOTACAO  \
# 9                             MINISTERIO DA FAZENDA               20101
# 76                  Universidade Federal da Paraíba               15000
# 144             Instituto Federal Sul-rio-grandense               15000
# 168               Fundação Universidade de Brasília               15000
# 262             Instituto Nacional do Seguro Social               33100
# ...                                             ...                 ...
# 710973          Instituto Nacional do Seguro Social               33100
# 711408                Universidade Federal da Bahia               15000
# 711457  Agência Nacional de Transportes Aquaviários               49100
# 711526          Instituto Nacional do Seguro Social               33100
# 711727   Universidade Tecnológica Federal do Paraná               15000
#
#                            ORGSUP_LOTACAO  COD_UORG_EXERCICIO  \
# 9                Presidência da República      17600000002916
# 76                 Ministério da Educação      26240000000137
# 144                Ministério da Educação      26436000000214
# 168                Ministério da Educação      26271000000629
# 262      MINISTERIO DA PREVIDENCIA SOCIAL      57202000008036
# ...                                   ...                 ...
# 710973   MINISTERIO DA PREVIDENCIA SOCIAL      57202000009532
# 711408             Ministério da Educação      26232000000195
# 711457  MINISTERIO DE PORTOS E AEROPORTOS      39251000000005
# 711526   MINISTERIO DA PREVIDENCIA SOCIAL      57202000012863
# 711727             Ministério da Educação      26258000001363
#
#                                   UORG_EXERCICIO  COD_ORG_EXERCICIO  \
# 9              PROC ESTADUAL DA FAZ NAC DO CEARA              17600
# 76                          CENTRO DE TECNOLOGIA              26240
# 144     PL-COIME - COORDENADORIA DE INSTALACAO E              26436
# 168                 COORDENADORIA DE ATENDIMENTO              26271
# 262                         APS B BARRA DO CORDA              57202
# ...                                          ...                ...
# 710973                  APS A SAO PAULO - CENTRO              57202
# 711408                        ESCOLA POLITECNICA              26232
# 711457                                 OUVIDORIA              39251
# 711526    SEC DE ANALISE  DE MANUT DE BENEFICIOS              57202
# 711727  ASSESSORIA APOIO TECNICO DE AUDIOVISUAIS              26258
#
#                                       ORG_EXERCICIO  COD_ORGSUP_EXERCICIO  \
# 9                             MINISTERIO DA FAZENDA                 20101
# 76                  Universidade Federal da Paraíba                 15000
# 144             Instituto Federal Sul-rio-grandense                 15000
# 168               Fundação Universidade de Brasília                 15000
# 262             Instituto Nacional do Seguro Social                 33100
# ...                                             ...                   ...
# 710973          Instituto Nacional do Seguro Social                 33100
# 711408                Universidade Federal da Bahia                 15000
# 711457  Agência Nacional de Transportes Aquaviários                 49100
# 711526          Instituto Nacional do Seguro Social                 33100
# 711727   Universidade Tecnológica Federal do Paraná                 15000
#
#                          ORGSUP_EXERCICIO  COD_TIPO_VINCULO TIPO_VINCULO  \
# 9                Presidência da República                 3       Outros
# 76                 Ministério da Educação                 3       Outros
# 144                Ministério da Educação                 3       Outros
# 168                Ministério da Educação                 3       Outros
# 262      MINISTERIO DA PREVIDENCIA SOCIAL                 3       Outros
# ...                                   ...               ...          ...
# 710973   MINISTERIO DA PREVIDENCIA SOCIAL                 3       Outros
# 711408             Ministério da Educação                 3       Outros
# 711457  MINISTERIO DE PORTOS E AEROPORTOS                 3       Outros
# 711526   MINISTERIO DA PREVIDENCIA SOCIAL                 3       Outros
# 711727             Ministério da Educação                 3       Outros
#
#          SITUACAO_VINCULO  DATA_INICIO_AFASTAMENTO  DATA_TERMINO_AFASTAMENTO  \
# 9       ESTAGIARIO SIGEPE                      NaN                       NaN
# 76      ESTAGIARIO SIGEPE                      NaN                       NaN
# 144     ESTAGIARIO SIGEPE                      NaN                       NaN
# 168     ESTAGIARIO SIGEPE                      NaN                       NaN
# 262     ESTAGIARIO SIGEPE                      NaN                       NaN
# ...                   ...                      ...                       ...
# 710973  ESTAGIARIO SIGEPE                      NaN                       NaN
# 711408  ESTAGIARIO SIGEPE                      NaN                       NaN
# 711457  ESTAGIARIO SIGEPE                      NaN                       NaN
# 711526  ESTAGIARIO SIGEPE                      NaN                       NaN
# 711727  ESTAGIARIO SIGEPE                      NaN                       NaN
#
#        REGIME_JURIDICO JORNADA_DE_TRABALHO DATA_INGRESSO_CARGOFUNCAO  \
# 9              ESTAGIO   20 HORAS SEMANAIS                       NaN
# 76             ESTAGIO   20 HORAS SEMANAIS                       NaN
# 144            ESTAGIO   20 HORAS SEMANAIS                       NaN
# 168            ESTAGIO   30 HORAS SEMANAIS                       NaN
# 262            ESTAGIO   30 HORAS SEMANAIS                       NaN
# ...                ...                 ...                       ...
# 710973         ESTAGIO   30 HORAS SEMANAIS                       NaN
# 711408         ESTAGIO   20 HORAS SEMANAIS                       NaN
# 711457         ESTAGIO   30 HORAS SEMANAIS                       NaN
# 711526         ESTAGIO   30 HORAS SEMANAIS                       NaN
# 711727         ESTAGIO   20 HORAS SEMANAIS                       NaN
#
#         DATA_NOMEACAO_CARGOFUNCAO DATA_INGRESSO_ORGAO  \
# 9                             NaN          18/12/2019
# 76                            NaN          14/02/2023
# 144                           NaN          17/12/2019
# 168                           NaN          17/12/2019
# 262                           NaN          13/12/2021
# ...                           ...                 ...
# 710973                        NaN          01/09/2020
# 711408                        NaN          15/06/2022
# 711457                        NaN          15/06/2022
# 711526                        NaN          17/12/2019
# 711727                        NaN          06/02/2023
#
#        DOCUMENTO_INGRESSO_SERVICOPUBLICO DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO  \
# 9                                    NaN                                  NaN
# 76                                   NaN                                  NaN
# 144                                  NaN                                  NaN
# 168                                  NaN                                  NaN
# 262                                  NaN                                  NaN
# ...                                  ...                                  ...
# 710973                               NaN                                  NaN
# 711408                               NaN                                  NaN
# 711457                               NaN                                  NaN
# 711526                               NaN                                  NaN
# 711727                               NaN                                  NaN
#
#         DIPLOMA_INGRESSO_CARGOFUNCAO DIPLOMA_INGRESSO_ORGAO  \
# 9                                NaN               PORTARIA
# 76                               NaN     NORMA COMPLEMENTAR
# 144                              NaN               PORTARIA
# 168                              NaN               PORTARIA
# 262                              NaN               CERTIDAO
# ...                              ...                    ...
# 710973                           NaN               PORTARIA
# 711408                           NaN               PORTARIA
# 711457                           NaN               PORTARIA
# 711526                           NaN               PORTARIA
# 711727                           NaN               CERTIDAO
#
#        DIPLOMA_INGRESSO_SERVICOPUBLICO  UF_EXERCICIO
# 9                             Inválido            -1
# 76                            Inválido            -1
# 144                           Inválido            -1
# 168                           Inválido            -1
# 262                           Inválido            -1
# ...                                ...           ...
# 710973                        Inválido            -1
# 711408                        Inválido            -1
# 711457                        Inválido            -1
# 711526                        Inválido            -1
# 711727                        Inválido            -1
#
# [16899 rows x 43 columns]

# %%
df_filtro = df_cadastro[df_cadastro["NOME"].str.contains("julia", case=False, na=False) &
            df_cadastro["UORG_EXERCICIO"].str.contains("vcp", case=False, na=False)]

display(df_filtro)
# Out:
#         Id_SERVIDOR_PORTAL                     NOME             CPF MATRICULA  \
# 364467           312281537  JULIA GERMANO EMANUELLI  ***.165.688-**   013****
# 369721           310277725  JULIANO FRANCISCO NEVES  ***.922.616-**   017****
#
#                                  DESCRICAO_CARGO CLASSE_CARGO  \
# 364467                                  Inválido          NaN
# 369721  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL            S
#
#         REFERENCIA_CARGO PADRAO_CARGO  NIVEL_CARGO SIGLA_FUNCAO  NIVEL_FUNCAO  \
# 364467               0.0          NaN          0.0           -1            -1
# 369721               0.0          002          0.0           -1            -1
#
#                 FUNCAO  CODIGO_ATIVIDADE     ATIVIDADE OPCAO_PARCIAL  \
# 364467  Sem informação                -1  Sem informaç           NaN
# 369721  Sem informação                -1  Sem informaç           NaN
#
#         COD_UORG_LOTACAO                          UORG_LOTACAO  \
# 364467                -3                              Inválido
# 369721    17600000001688  ALF/VCP/ALF RFB NO AER INT VIRACOPOS
#
#         COD_ORG_LOTACAO            ORG_LOTACAO  COD_ORGSUP_LOTACAO  \
# 364467            17600  MINISTERIO DA FAZENDA               20101
# 369721            17600  MINISTERIO DA FAZENDA               20101
#
#                   ORGSUP_LOTACAO  COD_UORG_EXERCICIO  \
# 364467  Presidência da República      17600000001688
# 369721  Presidência da República      17600000001698
#
#                                  UORG_EXERCICIO  COD_ORG_EXERCICIO  \
# 364467     ALF/VCP/ALF RFB NO AER INT VIRACOPOS              17600
# 369721  ALF/VCP/SERVICO DE VIG REP CONTR DESCAM              17600
#
#                 ORG_EXERCICIO  COD_ORGSUP_EXERCICIO          ORGSUP_EXERCICIO  \
# 364467  MINISTERIO DA FAZENDA                 20101  Presidência da República
# 369721  MINISTERIO DA FAZENDA                 20101  Presidência da República
#
#         COD_TIPO_VINCULO TIPO_VINCULO   SITUACAO_VINCULO  \
# 364467                 3       Outros  ESTAGIARIO SIGEPE
# 369721                 2        Cargo   ATIVO PERMANENTE
#
#         DATA_INICIO_AFASTAMENTO  DATA_TERMINO_AFASTAMENTO  \
# 364467                      NaN                       NaN
# 369721                      NaN                       NaN
#
#               REGIME_JURIDICO JORNADA_DE_TRABALHO DATA_INGRESSO_CARGOFUNCAO  \
# 364467                ESTAGIO   20 HORAS SEMANAIS                       NaN
# 369721  REGIME JURIDICO UNICO   40 HORAS SEMANAIS                30/12/2016
#
#         DATA_NOMEACAO_CARGOFUNCAO DATA_INGRESSO_ORGAO  \
# 364467                        NaN          18/12/2019
# 369721                        NaN          19/06/2023
#
#        DOCUMENTO_INGRESSO_SERVICOPUBLICO DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO  \
# 364467                               NaN                                  NaN
# 369721                              1376                           01/07/2010
#
#         DIPLOMA_INGRESSO_CARGOFUNCAO DIPLOMA_INGRESSO_ORGAO  \
# 364467                           NaN               PORTARIA
# 369721                           NaN                    LEI
#
#        DIPLOMA_INGRESSO_SERVICOPUBLICO  UF_EXERCICIO
# 364467                        Inválido            -1
# 369721                        PORTARIA            -1

# %%
df_filtro = df_cadastro[df_cadastro["NOME"].str.contains("FERNANDO AUGUSTO SAMPAIO BONAFE FERNANDES", case=False, na=False)]

display(df_filtro)
# Out:
#         Id_SERVIDOR_PORTAL                                       NOME  \
# 233601           310868397  FERNANDO AUGUSTO SAMPAIO BONAFE FERNANDES
#
#                    CPF MATRICULA                         DESCRICAO_CARGO  \
# 233601  ***.409.137-**   010****  ANALISTA TRIBUTARIO REC FEDERAL BRASIL
#
#        CLASSE_CARGO  REFERENCIA_CARGO PADRAO_CARGO  NIVEL_CARGO SIGLA_FUNCAO  \
# 233601            S               0.0          001          0.0           -1
#
#         NIVEL_FUNCAO          FUNCAO  CODIGO_ATIVIDADE     ATIVIDADE  \
# 233601            -1  Sem informação                -1  Sem informaç
#
#        OPCAO_PARCIAL  COD_UORG_LOTACAO                          UORG_LOTACAO  \
# 233601           NaN    17600000001688  ALF/VCP/ALF RFB NO AER INT VIRACOPOS
#
#         COD_ORG_LOTACAO            ORG_LOTACAO  COD_ORGSUP_LOTACAO  \
# 233601            17600  MINISTERIO DA FAZENDA               20101
#
#                   ORGSUP_LOTACAO  COD_UORG_EXERCICIO  \
# 233601  Presidência da República      17600000001688
#
#                               UORG_EXERCICIO  COD_ORG_EXERCICIO  \
# 233601  ALF/VCP/ALF RFB NO AER INT VIRACOPOS              17600
#
#                 ORG_EXERCICIO  COD_ORGSUP_EXERCICIO          ORGSUP_EXERCICIO  \
# 233601  MINISTERIO DA FAZENDA                 20101  Presidência da República
#
#         COD_TIPO_VINCULO TIPO_VINCULO  SITUACAO_VINCULO  \
# 233601                 2        Cargo  ATIVO PERMANENTE
#
#         DATA_INICIO_AFASTAMENTO  DATA_TERMINO_AFASTAMENTO  \
# 233601                      NaN                       NaN
#
#               REGIME_JURIDICO JORNADA_DE_TRABALHO DATA_INGRESSO_CARGOFUNCAO  \
# 233601  REGIME JURIDICO UNICO   40 HORAS SEMANAIS                30/12/2016
#
#         DATA_NOMEACAO_CARGOFUNCAO DATA_INGRESSO_ORGAO  \
# 233601                        NaN          19/06/2023
#
#        DOCUMENTO_INGRESSO_SERVICOPUBLICO DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO  \
# 233601                               719                           24/02/2014
#
#         DIPLOMA_INGRESSO_CARGOFUNCAO DIPLOMA_INGRESSO_ORGAO  \
# 233601                           NaN                    LEI
#
#        DIPLOMA_INGRESSO_SERVICOPUBLICO  UF_EXERCICIO
# 233601                        PORTARIA            -1
