# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %%
# Especifique o caminho para o seu arquivo CSV
caminho_arquivo = '/home/carolcardoso/git/ProgramaEstagio/informações/despesas_publicas/202401_Despesas.csv'

df = pd.read_csv(caminho_arquivo, delimiter=';', encoding='latin1')

display(df)
# Out:
#       Ano e mês do lançamento  Código Órgão Superior  \
# 0                     2024/01                  26000
# 1                     2024/01                  26000
# 2                     2024/01                  33000
# 3                     2024/01                  51000
# 4                     2024/01                  26000
# ...                       ...                    ...
# 48012                 2024/01                  36000
# 48013                 2024/01                  26000
# 48014                 2024/01                  81000
# 48015                 2024/01                  26000
# 48016                 2024/01                  52000
#
#                                Nome Órgão Superior  Código Órgão Subordinado  \
# 0                           Ministério da Educação                     26440
# 1                           Ministério da Educação                     26443
# 2                 Ministério da Previdência Social                     37202
# 3                            Ministério do Esporte                     51000
# 4                           Ministério da Educação                     26252
# ...                                            ...                       ...
# 48012                          Ministério da Saúde                     36000
# 48013                       Ministério da Educação                     26403
# 48014  Ministério dos Direitos Humanos e Cidadania                     81000
# 48015                       Ministério da Educação                     26443
# 48016                         Ministério da Defesa                     52121
#
#                                   Nome Órgão Subordinado  \
# 0                  Universidade Federal da Fronteira Sul
# 1            Empresa Brasileira de Serviços Hospitalares
# 2                    Instituto Nacional do Seguro Social
# 3      Ministério do Esporte - Unidades com vínculo d...
# 4                 Universidade Federal de Campina Grande
# ...                                                  ...
# 48012  Ministério da Saúde - Unidades com vínculo direto
# 48013                      Instituto Federal do Amazonas
# 48014  Ministério dos Direitos Humanos e Cidadania - ...
# 48015        Empresa Brasileira de Serviços Hospitalares
# 48016                                Comando do Exército
#
#        Código Unidade Gestora                          Nome Unidade Gestora  \
# 0                      158517         UNIVERSIDADE FEDERAL DA FRONTEIRA SUL
# 1                      155021                 HOSPITAL DAS CLINICAS DA UFMG
# 2                      510178           SUPERINTENDENCIA REGIONAL SUDESTE I
# 3                      180016  AUTORIDADE BRASILEIRA DE CONTROLE DE DOPAGEM
# 4                      158195        UNIVERSIDADE FEDERAL DE CAMPINA GRANDE
# ...                       ...                                           ...
# 48012                  257037        DISTRITO SANIT.ESP.INDIGENA - ARAGUAIA
# 48013                  155422                      IFAM - CAMPUS MANACAPURU
# 48014                  810005         COORDENACAO-GERAL DE LOGISTICA - MDHC
# 48015                  155912         HOSPITAL UNIVERSITARIO JULIO BANDEIRA
# 48016                  160156        44 BATALHAO INFANTARIA MTZ PATRIMONIAL
#
#        Código Gestão                                  Nome Gestão  \
# 0            26440.0        UNIVERSIDADE FEDERAL DA FRONTEIRA SUL
# 1            26443.0  EMPRESA BRASILEIRA DE SERVICOS HOSPITALARES
# 2            57202.0          INSTITUTO NACIONAL DO SEGURO SOCIAL
# 3                1.0                             TESOURO NACIONAL
# 4            15281.0       UNIVERSIDADE FEDERAL DE CAMPINA GRANDE
# ...              ...                                          ...
# 48012            1.0                             TESOURO NACIONAL
# 48013        26403.0    INST.FED.DE EDUC.,CIENC.E TEC.DO AMAZONAS
# 48014            1.0                             TESOURO NACIONAL
# 48015            NaN                                          NaN
# 48016            NaN                                          NaN
#
#        Código Unidade Orçamentária  \
# 0                            26440
# 1                            36901
# 2                            33201
# 3                            51101
# 4                            26252
# ...                            ...
# 48012                        36901
# 48013                        26403
# 48014                        81101
# 48015                        26443
# 48016                        52121
#
#                           Nome Unidade Orçamentária  Código Função  \
# 0             UNIVERSIDADE FEDERAL DA FRONTEIRA SUL             12
# 1                           FUNDO NACIONAL DE SAUDE             10
# 2               INSTITUTO NACIONAL DO SEGURO SOCIAL              9
# 3                             MINISTERIO DO ESPORTE             27
# 4            UNIVERSIDADE FEDERAL DE CAMPINA GRANDE             12
# ...                                             ...            ...
# 48012                       FUNDO NACIONAL DE SAUDE             10
# 48013     INST.FED.DE EDUC.,CIENC.E TEC.DO AMAZONAS             12
# 48014         MINISTERIO DOS DIREITOS HUMANOS - MDH             14
# 48015  EMPRESA BRASIL.DE SERV.HOSPITALARES - EBSERH             12
# 48016                           COMANDO DO EXERCITO              5
#
#                  Nome Função  Código Subfução  \
# 0                   Educação              364
# 1                      Saúde              302
# 2         Previdência social              122
# 3           Desporto e lazer              811
# 4                   Educação              364
# ...                      ...              ...
# 48012                  Saúde              423
# 48013               Educação              363
# 48014  Direitos da cidadania              422
# 48015               Educação              302
# 48016        Defesa nacional              153
#
#                                   Nome Subfunção  \
# 0                                Ensino superior
# 1          Assistência hospitalar e ambulatorial
# 2                            Administração geral
# 3                         Desporto de rendimento
# 4                                Ensino superior
# ...                                          ...
# 48012            Assistência aos povos indígenas
# 48013                        Ensino profissional
# 48014  Direitos individuais, coletivos e difusos
# 48015      Assistência hospitalar e ambulatorial
# 48016                           Defesa terrestre
#
#        Código Programa Orçamentário  \
# 0                              5013
# 1                              5018
# 2                                32
# 3                              5026
# 4                              5013
# ...                             ...
# 48012                          5022
# 48013                          5012
# 48014                          5034
# 48015                          5013
# 48016                          6012
#
#                               Nome Programa Orçamentário Código Ação  \
# 0      EDUCACAO SUPERIOR - GRADUACAO, POS-GRADUACAO, ...        20RK
# 1                          ATENCAO ESPECIALIZADA A SAUDE        8585
# 2      PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        21FT
# 3                                                ESPORTE        211Z
# 4      EDUCACAO SUPERIOR - GRADUACAO, POS-GRADUACAO, ...        20RK
# ...                                                  ...         ...
# 48012  PROTECAO, PROMOCAO E RECUPERACAO DA SAUDE INDI...        20YP
# 48013                EDUCACAO PROFISSIONAL E TECNOLOGICA        2994
# 48014  PROTECAO A VIDA, FORTALECIMENTO DA FAMILIA, PR...        21AR
# 48015  EDUCACAO SUPERIOR - GRADUACAO, POS-GRADUACAO, ...        4086
# 48016                                    DEFESA NACIONAL        219D
#
#                                                Nome Ação  \
# 0      FUNCIONAMENTO DE INSTITUICOES FEDERAIS DE ENSI...
# 1      ATENCAO A SAUDE DA POPULACAO PARA PROCEDIMENTO...
# 2                ATENDIMENTO DA CLIENTELA PREVIDENCIARIA
# 3      DESENVOLVIMENTO E EXECUCAO DA POLITICA NACIONA...
# 4      FUNCIONAMENTO DE INSTITUICOES FEDERAIS DE ENSI...
# ...                                                  ...
# 48012  PROMOCAO, PROTECAO E RECUPERACAO DA SAUDE INDI...
# 48013  ASSISTENCIA AOS ESTUDANTES DAS INSTITUICOES FE...
# 48014   PROMOCAO E DEFESA DE DIREITOS HUMANOS PARA TODOS
# 48015  FUNCIONAMENTO E GESTAO DE INSTITUICOES HOSPITA...
# 48016  ADEQUACAO DE ATIVOS DE INFRAESTRUTURA DAS ORGA...
#
#       Código Plano Orçamentário  \
# 0                          0000
# 1                          0005
# 2                          0001
# 3                          0000
# 4                          0000
# ...                         ...
# 48012                      0003
# 48013                      0000
# 48014                      000Z
# 48015                      0000
# 48016                      0000
#
#                                       Plano Orçamentário  \
# 0      FUNCIONAMENTO DE INSTITUICOES FEDERAIS DE ENSI...
# 1         FUNDO DE ACOES ESTRATEGICAS E COMPENSACAO-FAEC
# 2                            CODIGO INEXISTENTE NO SIAFI
# 3      DESENVOLVIMENTO E EXECUCAO DA POLITICA NACIONA...
# 4      FUNCIONAMENTO DE INSTITUICOES FEDERAIS DE ENSI...
# ...                                                  ...
# 48012  ESTRUTURACAO DE UNIDADES DE SAUDE E DSEI PARA ...
# 48013  ASSISTENCIA AOS ESTUDANTES DAS INSTITUICOES FE...
# 48014                    PROMOCAO DA LIBERDADE RELIGIOSA
# 48015  FUNCIONAMENTO E GESTAO DE INSTITUICOES HOSPITA...
# 48016  ADEQUACAO DE ATIVOS DE INFRAESTRUTURA DAS ORGA...
#
#       Código Programa Governo Nome Programa Governo   UF Município  \
# 0                          00        Sem informação  NaN       NaN
# 1                          00        Sem informação   MG       NaN
# 2                          00        Sem informação  NaN       NaN
# 3                          00        Sem informação  NaN       NaN
# 4                          00        Sem informação   PB       NaN
# ...                       ...                   ...  ...       ...
# 48012                      00        Sem informação  NaN       NaN
# 48013                      00        Sem informação   AM       NaN
# 48014                      00        Sem informação  NaN       NaN
# 48015                      00        Sem informação  NaN       NaN
# 48016                      00        Sem informação  NaN       NaN
#
#       Código Subtítulo                                     Nome Subtítulo  \
# 0             20RK0040  FUNCIONAMENTO DE INSTITUICOES FEDERAI - NA REG...
# 1             85850031  ATENCAO A SAUDE DA POPULACAO PARA PRO - NO EST...
# 2             21FT0001   ATENDIMENTO DA CLIENTELA PREVIDENCIAR - NACIONAL
# 3             211Z0001   DESENVOLVIMENTO E EXECUCAO DA POLITIC - NACIONAL
# 4             20RK0025  FUNCIONAMENTO DE INSTITUICOES FEDERAI - NO EST...
# ...                ...                                                ...
# 48012         20YP0001   PROMOCAO, PROTECAO E RECUPERACAO DA S - NACIONAL
# 48013         29940013  ASSISTENCIA AOS ESTUDANTES DAS INSTIT - NO EST...
# 48014         21AR0001   PROMOCAO E DEFESA DE DIREITOS HUMANOS - NACIONAL
# 48015         40860001   FUNCIONAMENTO E GESTAO DE INSTITUICOE - NACIONAL
# 48016         219D0001   ADEQUACAO DE ATIVOS DE INFRAESTRUTURA - NACIONAL
#
#        Código Localizador                               Nome Localizador  \
# 0                      40  FUNCIONAMENTO DE INSTITUICOES FEDERAI - NA RE
# 1                      31  ATENCAO A SAUDE DA POPULACAO PARA PRO - NO ES
# 2                       1  ATENDIMENTO DA CLIENTELA PREVIDENCIAR - NACIO
# 3                       1  DESENVOLVIMENTO E EXECUCAO DA POLITIC - NACIO
# 4                      25  FUNCIONAMENTO DE INSTITUICOES FEDERAI - NO ES
# ...                   ...                                            ...
# 48012                   1  PROMOCAO, PROTECAO E RECUPERACAO DA S - NACIO
# 48013                  13  ASSISTENCIA AOS ESTUDANTES DAS INSTIT - NO ES
# 48014                   1  PROMOCAO E DEFESA DE DIREITOS HUMANOS - NACIO
# 48015                   1  FUNCIONAMENTO E GESTAO DE INSTITUICOE - NACIO
# 48016                   1  ADEQUACAO DE ATIVOS DE INFRAESTRUTURA - NACIO
#
#        Sigla Localizador Descrição Complementar Localizador  \
# 0                     -1                     Sem informação
# 1                     -1                     Sem informação
# 2                     -1                     Sem informação
# 3                     -1                     Sem informação
# 4                     -1                     Sem informação
# ...                  ...                                ...
# 48012                 -1                     Sem informação
# 48013                 -1                     Sem informação
# 48014                 -1                     Sem informação
# 48015                 -1                     Sem informação
# 48016                 -1                     Sem informação
#
#        Código Autor Emenda        Nome Autor Emenda  \
# 0                      NaN               SEM EMENDA
# 1                      NaN               SEM EMENDA
# 2                      NaN               SEM EMENDA
# 3                      NaN               SEM EMENDA
# 4                      NaN               SEM EMENDA
# ...                    ...                      ...
# 48012                  NaN               SEM EMENDA
# 48013                  NaN               SEM EMENDA
# 48014                  NaN               SEM EMENDA
# 48015                  NaN               SEM EMENDA
# 48016         2.022396e+11  DR. LEONARDO / EMENDA 5
#
#        Código Categoria Econômica Nome Categoria Econômica  \
# 0                               3       DESPESAS CORRENTES
# 1                               3       DESPESAS CORRENTES
# 2                               3       DESPESAS CORRENTES
# 3                               3       DESPESAS CORRENTES
# 4                               3       DESPESAS CORRENTES
# ...                           ...                      ...
# 48012                           3       DESPESAS CORRENTES
# 48013                           3       DESPESAS CORRENTES
# 48014                           3       DESPESAS CORRENTES
# 48015                           3       DESPESAS CORRENTES
# 48016                           4      DESPESAS DE CAPITAL
#
#        Código Grupo de Despesa      Nome Grupo de Despesa  \
# 0                            3  Outras Despesas Correntes
# 1                            3  Outras Despesas Correntes
# 2                            3  Outras Despesas Correntes
# 3                            3  Outras Despesas Correntes
# 4                            3  Outras Despesas Correntes
# ...                        ...                        ...
# 48012                        3  Outras Despesas Correntes
# 48013                        3  Outras Despesas Correntes
# 48014                        3  Outras Despesas Correntes
# 48015                        3  Outras Despesas Correntes
# 48016                        4              Investimentos
#
#        Código Elemento de Despesa  \
# 0                              18
# 1                              39
# 2                              47
# 3                              47
# 4                              47
# ...                           ...
# 48012                          30
# 48013                          32
# 48014                          33
# 48015                          39
# 48016                          51
#
#                           Nome Elemento de Despesa  \
# 0                  Auxílio Financeiro a Estudantes
# 1      Outros Serviços de Terceiros - Pessoa Juríd
# 2           Obrigações Tributárias e Contributivas
# 3           Obrigações Tributárias e Contributivas
# 4           Obrigações Tributárias e Contributivas
# ...                                            ...
# 48012                          Material de Consumo
# 48013   Material, Bem ou Serviço para Distribuição
# 48014           Passagens e Despesas com Locomoção
# 48015  Outros Serviços de Terceiros - Pessoa Juríd
# 48016                          Obras e Instalações
#
#        Código Modalidade da Despesa  \
# 0                                90
# 1                                90
# 2                                90
# 3                                91
# 4                                90
# ...                             ...
# 48012                            90
# 48013                            90
# 48014                            90
# 48015                            90
# 48016                            90
#
#                                    Modalidade da Despesa Valor Empenhado (R$)  \
# 0                                     Aplicações Diretas                 0,00
# 1                                     Aplicações Diretas                 0,00
# 2                                     Aplicações Diretas            119913,15
# 3      Aplicação Direta Decorrente de Operação entre ...                 0,00
# 4                                     Aplicações Diretas                 0,00
# ...                                                  ...                  ...
# 48012                                 Aplicações Diretas                 0,00
# 48013                                 Aplicações Diretas                 0,00
# 48014                                 Aplicações Diretas                 0,00
# 48015                                 Aplicações Diretas                 0,00
# 48016                                 Aplicações Diretas                 0,00
#
#       Valor Liquidado (R$) Valor Pago (R$)  \
# 0                     0,00            0,00
# 1                     0,00            0,00
# 2                103035,43        35695,99
# 3                     0,00            0,00
# 4                     0,00            0,00
# ...                    ...             ...
# 48012                 0,00            0,00
# 48013                 0,00            0,00
# 48014                 0,00            0,00
# 48015                 0,00            0,00
# 48016                 0,00            0,00
#
#       Valor Restos a Pagar Inscritos (R$) Valor Restos a Pagar Cancelado (R$)  \
# 0                                    0,00                                0,00
# 1                                    0,00                                0,00
# 2                                    0,00                                0,00
# 3                                    0,00                                0,00
# 4                                    0,00                                0,00
# ...                                   ...                                 ...
# 48012                                0,00                                0,00
# 48013                                0,00                                0,00
# 48014                                0,00                                0,00
# 48015                                0,00                                0,00
# 48016                                0,02                                0,00
#
#       Valor Restos a Pagar Pagos (R$)
# 0                            28561,59
# 1                           625252,77
# 2                                0,00
# 3                            24474,80
# 4                               54,13
# ...                               ...
# 48012                       418100,93
# 48013                         5611,35
# 48014                        30835,96
# 48015                         2548,37
# 48016                            0,00
#
# [48017 rows x 47 columns]

# %%
df_rfb = df[df['Nome Unidade Gestora'].str.contains('rfb', case=False, na=False)]

display(df_rfb)
# Out:
#       Ano e mês do lançamento  Código Órgão Superior    Nome Órgão Superior  \
# 8                     2024/01                  25000  Ministério da Fazenda
# 45                    2024/01                  25000  Ministério da Fazenda
# 157                   2024/01                  25000  Ministério da Fazenda
# 279                   2024/01                  25000  Ministério da Fazenda
# 291                   2024/01                  25000  Ministério da Fazenda
# ...                       ...                    ...                    ...
# 46679                 2024/01                  25000  Ministério da Fazenda
# 46683                 2024/01                  25000  Ministério da Fazenda
# 46900                 2024/01                  25000  Ministério da Fazenda
# 47296                 2024/01                  25000  Ministério da Fazenda
# 47715                 2024/01                  25000  Ministério da Fazenda
#
#        Código Órgão Subordinado  \
# 8                         25000
# 45                        25000
# 157                       25000
# 279                       25000
# 291                       25000
# ...                         ...
# 46679                     25000
# 46683                     25000
# 46900                     25000
# 47296                     25000
# 47715                     25000
#
#                                   Nome Órgão Subordinado  \
# 8      Ministério da Fazenda - Unidades com vínculo d...
# 45     Ministério da Fazenda - Unidades com vínculo d...
# 157    Ministério da Fazenda - Unidades com vínculo d...
# 279    Ministério da Fazenda - Unidades com vínculo d...
# 291    Ministério da Fazenda - Unidades com vínculo d...
# ...                                                  ...
# 46679  Ministério da Fazenda - Unidades com vínculo d...
# 46683  Ministério da Fazenda - Unidades com vínculo d...
# 46900  Ministério da Fazenda - Unidades com vínculo d...
# 47296  Ministério da Fazenda - Unidades com vínculo d...
# 47715  Ministério da Fazenda - Unidades com vínculo d...
#
#        Código Unidade Gestora                           Nome Unidade Gestora  \
# 8                      170178              DELEGACIA DA RFB EM CAXIAS DO SUL
# 45                     170205                 DELEGACIA DA RFB EM RIO BRANCO
# 157                    170094                   DELEGACIA DA RFB EM VARGINHA
# 279                    170312  DELEGACIA DE ADM.TRIBUTARIA DA RFB EM S.PAULO
# 291                    170178              DELEGACIA DA RFB EM CAXIAS DO SUL
# ...                       ...                                            ...
# 46679                  170183                DELEGACIA DA RFB EM SANTA MARIA
# 46683                  170078      SUPERINTENDENCIA REGIONAL DA RFB NA 5A RF
# 46900                  170136                   DELEGACIA DA RFB EM CAMPINAS
# 47296                  170219                   DELEGACIA DA RFB EM SANTAREM
# 47715                  170156      SUPERINTENDENCIA REGIONAL DA RFB NA 9A RF
#
#        Código Gestão       Nome Gestão  Código Unidade Orçamentária  \
# 8                1.0  TESOURO NACIONAL                        25104
# 45               1.0  TESOURO NACIONAL                        25103
# 157              1.0  TESOURO NACIONAL                        25103
# 279              1.0  TESOURO NACIONAL                        25103
# 291              1.0  TESOURO NACIONAL                        25103
# ...              ...               ...                          ...
# 46679            1.0  TESOURO NACIONAL                        25103
# 46683            1.0  TESOURO NACIONAL                        12101
# 46900            1.0  TESOURO NACIONAL                        25103
# 47296            1.0  TESOURO NACIONAL                        25103
# 47715            1.0  TESOURO NACIONAL                        25103
#
#                        Nome Unidade Orçamentária  Código Função  \
# 8         PROCURADORIA GERAL DA FAZENDA NACIONAL              4
# 45     SEC ESPECIAL DA RECEITA FEDERAL DO BRASIL              4
# 157    SEC ESPECIAL DA RECEITA FEDERAL DO BRASIL              4
# 279    SEC ESPECIAL DA RECEITA FEDERAL DO BRASIL              4
# 291    SEC ESPECIAL DA RECEITA FEDERAL DO BRASIL              4
# ...                                          ...            ...
# 46679  SEC ESPECIAL DA RECEITA FEDERAL DO BRASIL              4
# 46683           JUSTICA FEDERAL DE PRIMEIRO GRAU              2
# 46900  SEC ESPECIAL DA RECEITA FEDERAL DO BRASIL              4
# 47296  SEC ESPECIAL DA RECEITA FEDERAL DO BRASIL              4
# 47715  SEC ESPECIAL DA RECEITA FEDERAL DO BRASIL              4
#
#          Nome Função  Código Subfução               Nome Subfunção  \
# 8      Administração              122          Administração geral
# 45     Administração              122          Administração geral
# 157    Administração              122          Administração geral
# 279    Administração              122          Administração geral
# 291    Administração              122          Administração geral
# ...              ...              ...                          ...
# 46679  Administração              125  Normatização e fiscalização
# 46683     Judiciária               61              Ação judiciária
# 46900  Administração              125  Normatização e fiscalização
# 47296  Administração              122          Administração geral
# 47715  Administração              125  Normatização e fiscalização
#
#        Código Programa Orçamentário  \
# 8                                32
# 45                               32
# 157                              32
# 279                              32
# 291                              32
# ...                             ...
# 46679                            32
# 46683                            33
# 46900                            32
# 47296                            32
# 47715                            32
#
#                               Nome Programa Orçamentário Código Ação  \
# 8      PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        2000
# 45     PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        2000
# 157    PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        2000
# 279    PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        2000
# 291    PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        2000
# ...                                                  ...         ...
# 46679  PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        20VF
# 46683  PROGRAMA DE GESTAO E MANUTENCAO DO PODER JUDIC...        4257
# 46900  PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        2237
# 47296  PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        2000
# 47715  PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...        2237
#
#                                              Nome Ação  \
# 8                             ADMINISTRACAO DA UNIDADE
# 45                            ADMINISTRACAO DA UNIDADE
# 157                           ADMINISTRACAO DA UNIDADE
# 279                           ADMINISTRACAO DA UNIDADE
# 291                           ADMINISTRACAO DA UNIDADE
# ...                                                ...
# 46679                     FORTALECIMENTO INSTITUCIONAL
# 46683          JULGAMENTO DE CAUSAS NA JUSTICA FEDERAL
# 46900  AUDITORIA E FISCALIZACAO TRIBUTARIA E ADUANEIRA
# 47296                         ADMINISTRACAO DA UNIDADE
# 47715  AUDITORIA E FISCALIZACAO TRIBUTARIA E ADUANEIRA
#
#       Código Plano Orçamentário  \
# 8                          0000
# 45                         0002
# 157                        0002
# 279                        0002
# 291                        0002
# ...                         ...
# 46679                      000A
# 46683                      0000
# 46900                      0003
# 47296                      0002
# 47715                      0003
#
#                                       Plano Orçamentário  \
# 8           ADMINISTRACAO DA UNIDADE - DESPESAS DIVERSAS
# 45                        ADMINISTRACAO DA UNIDADE - RFB
# 157                       ADMINISTRACAO DA UNIDADE - RFB
# 279                       ADMINISTRACAO DA UNIDADE - RFB
# 291                       ADMINISTRACAO DA UNIDADE - RFB
# ...                                                  ...
# 46679  INTERVENCOES NA LOGISTICA, ADEQUACAO E REFORMA...
# 46683  JULGAMENTO DE CAUSAS NA JUSTICA FEDERAL - DESP...
# 46900   OPERACOES DE FISCALIZACAO TRIBUTARIA E ADUANEIRA
# 47296                     ADMINISTRACAO DA UNIDADE - RFB
# 47715   OPERACOES DE FISCALIZACAO TRIBUTARIA E ADUANEIRA
#
#       Código Programa Governo Nome Programa Governo   UF Município  \
# 8                          00        Sem informação  NaN       NaN
# 45                         00        Sem informação  NaN       NaN
# 157                        00        Sem informação  NaN       NaN
# 279                        00        Sem informação  NaN       NaN
# 291                        00        Sem informação  NaN       NaN
# ...                       ...                   ...  ...       ...
# 46679                      00        Sem informação  NaN       NaN
# 46683                      00        Sem informação  NaN       NaN
# 46900                      00        Sem informação  NaN       NaN
# 47296                      00        Sem informação  NaN       NaN
# 47715                      00        Sem informação  NaN       NaN
#
#       Código Subtítulo                                    Nome Subtítulo  \
# 8             20000001         ADMINISTRACAO DA UNIDADE       - NACIONAL
# 45            20000001         ADMINISTRACAO DA UNIDADE       - NACIONAL
# 157           20000001         ADMINISTRACAO DA UNIDADE       - NACIONAL
# 279           20000001         ADMINISTRACAO DA UNIDADE       - NACIONAL
# 291           20000001         ADMINISTRACAO DA UNIDADE       - NACIONAL
# ...                ...                                               ...
# 46679         20VF0001       FORTALECIMENTO INSTITUCIONAL     - NACIONAL
# 46683         42570001  JULGAMENTO DE CAUSAS NA JUSTICA FEDER - NACIONAL
# 46900         22370001  AUDITORIA E FISCALIZACAO TRIBUTARIA E - NACIONAL
# 47296         20000001         ADMINISTRACAO DA UNIDADE       - NACIONAL
# 47715         22370001  AUDITORIA E FISCALIZACAO TRIBUTARIA E - NACIONAL
#
#        Código Localizador                               Nome Localizador  \
# 8                       1      ADMINISTRACAO DA UNIDADE       - NACIONAL
# 45                      1      ADMINISTRACAO DA UNIDADE       - NACIONAL
# 157                     1      ADMINISTRACAO DA UNIDADE       - NACIONAL
# 279                     1      ADMINISTRACAO DA UNIDADE       - NACIONAL
# 291                     1      ADMINISTRACAO DA UNIDADE       - NACIONAL
# ...                   ...                                            ...
# 46679                   1    FORTALECIMENTO INSTITUCIONAL     - NACIONAL
# 46683                   1  JULGAMENTO DE CAUSAS NA JUSTICA FEDER - NACIO
# 46900                   1  AUDITORIA E FISCALIZACAO TRIBUTARIA E - NACIO
# 47296                   1      ADMINISTRACAO DA UNIDADE       - NACIONAL
# 47715                   1  AUDITORIA E FISCALIZACAO TRIBUTARIA E - NACIO
#
#        Sigla Localizador Descrição Complementar Localizador  \
# 8                     -1                     Sem informação
# 45                    -1                     Sem informação
# 157                   -1                     Sem informação
# 279                   -1                     Sem informação
# 291                   -1                     Sem informação
# ...                  ...                                ...
# 46679                 -1                     Sem informação
# 46683                 -1                     Sem informação
# 46900                 -1                     Sem informação
# 47296                 -1                     Sem informação
# 47715                 -1                     Sem informação
#
#        Código Autor Emenda Nome Autor Emenda  Código Categoria Econômica  \
# 8                      NaN        SEM EMENDA                           3
# 45                     NaN        SEM EMENDA                           3
# 157                    NaN        SEM EMENDA                           3
# 279                    NaN        SEM EMENDA                           3
# 291                    NaN        SEM EMENDA                           3
# ...                    ...               ...                         ...
# 46679                  NaN        SEM EMENDA                           4
# 46683                  NaN        SEM EMENDA                           3
# 46900                  NaN        SEM EMENDA                           3
# 47296                  NaN        SEM EMENDA                           3
# 47715                  NaN        SEM EMENDA                           3
#
#       Nome Categoria Econômica  Código Grupo de Despesa  \
# 8           DESPESAS CORRENTES                        3
# 45          DESPESAS CORRENTES                        3
# 157         DESPESAS CORRENTES                        3
# 279         DESPESAS CORRENTES                        3
# 291         DESPESAS CORRENTES                        3
# ...                        ...                      ...
# 46679      DESPESAS DE CAPITAL                        4
# 46683       DESPESAS CORRENTES                        3
# 46900       DESPESAS CORRENTES                        3
# 47296       DESPESAS CORRENTES                        3
# 47715       DESPESAS CORRENTES                        3
#
#            Nome Grupo de Despesa  Código Elemento de Despesa  \
# 8      Outras Despesas Correntes                          39
# 45     Outras Despesas Correntes                          39
# 157    Outras Despesas Correntes                          36
# 279    Outras Despesas Correntes                          39
# 291    Outras Despesas Correntes                          39
# ...                          ...                         ...
# 46679              Investimentos                          51
# 46683  Outras Despesas Correntes                          39
# 46900  Outras Despesas Correntes                          39
# 47296  Outras Despesas Correntes                          39
# 47715  Outras Despesas Correntes                          37
#
#                           Nome Elemento de Despesa  \
# 8      Outros Serviços de Terceiros - Pessoa Juríd
# 45     Outros Serviços de Terceiros - Pessoa Juríd
# 157    Outros Serviços de Terceiros - Pessoa Físic
# 279    Outros Serviços de Terceiros - Pessoa Juríd
# 291    Outros Serviços de Terceiros - Pessoa Juríd
# ...                                            ...
# 46679                          Obras e Instalações
# 46683  Outros Serviços de Terceiros - Pessoa Juríd
# 46900  Outros Serviços de Terceiros - Pessoa Juríd
# 47296  Outros Serviços de Terceiros - Pessoa Juríd
# 47715                       Locação de Mão-de-Obra
#
#        Código Modalidade da Despesa Modalidade da Despesa  \
# 8                                90    Aplicações Diretas
# 45                               90    Aplicações Diretas
# 157                              90    Aplicações Diretas
# 279                              90    Aplicações Diretas
# 291                              90    Aplicações Diretas
# ...                             ...                   ...
# 46679                            90    Aplicações Diretas
# 46683                            90    Aplicações Diretas
# 46900                            90    Aplicações Diretas
# 47296                            90    Aplicações Diretas
# 47715                            90    Aplicações Diretas
#
#       Valor Empenhado (R$) Valor Liquidado (R$) Valor Pago (R$)  \
# 8                 43718,86                 0,00            0,00
# 45                    0,00                 0,00            0,00
# 157                 100,00                 0,00            0,00
# 279                 110,00                 3,46            3,46
# 291              456316,28                 0,00            0,00
# ...                    ...                  ...             ...
# 46679                 0,00                 0,00            0,00
# 46683                 0,00                 0,00            0,00
# 46900                 0,00                 0,00            0,00
# 47296              5000,00                 0,00            0,00
# 47715                 0,00                 0,00            0,00
#
#       Valor Restos a Pagar Inscritos (R$) Valor Restos a Pagar Cancelado (R$)  \
# 8                                    0,00                                0,00
# 45                                   0,00                                0,00
# 157                                  0,00                                0,00
# 279                                  0,00                                0,00
# 291                                  0,00                                0,00
# ...                                   ...                                 ...
# 46679                                0,00                                0,00
# 46683                                0,00                                0,00
# 46900                                0,00                                0,00
# 47296                                0,00                                0,00
# 47715                                0,00                                0,00
#
#       Valor Restos a Pagar Pagos (R$)
# 8                            46002,06
# 45                           43688,42
# 157                          69792,23
# 279                         357639,20
# 291                         334575,87
# ...                               ...
# 46679                       297674,75
# 46683                        15400,67
# 46900                         8845,51
# 47296                            0,00
# 47715                         6096,27
#
# [421 rows x 47 columns]

# %%
# Selecionar colunas específicas
colunas_desejadas = ['Ano e mês do lançamento', 'Nome Órgão Superior', 'Nome Unidade Gestora',
                     'Plano Orçamentário', 'Nome Categoria Econômica', 'Nome Grupo de Despesa', 'Nome Elemento de Despesa',
                     'Modalidade da Despesa', 'Valor Empenhado (R$)', 'Valor Liquidado (R$)', 'Valor Pago (R$)',
                     'Valor Restos a Pagar Inscritos (R$)', 'Valor Restos a Pagar Cancelado (R$)', 
                     'Valor Restos a Pagar Pagos (R$)']
df_selecionado = df_rfb[colunas_desejadas]

# Exibir as colunas selecionadas
display(df_selecionado)
# Out:
#       Ano e mês do lançamento    Nome Órgão Superior  \
# 8                     2024/01  Ministério da Fazenda
# 45                    2024/01  Ministério da Fazenda
# 157                   2024/01  Ministério da Fazenda
# 279                   2024/01  Ministério da Fazenda
# 291                   2024/01  Ministério da Fazenda
# ...                       ...                    ...
# 46679                 2024/01  Ministério da Fazenda
# 46683                 2024/01  Ministério da Fazenda
# 46900                 2024/01  Ministério da Fazenda
# 47296                 2024/01  Ministério da Fazenda
# 47715                 2024/01  Ministério da Fazenda
#
#                                 Nome Unidade Gestora  \
# 8                  DELEGACIA DA RFB EM CAXIAS DO SUL
# 45                    DELEGACIA DA RFB EM RIO BRANCO
# 157                     DELEGACIA DA RFB EM VARGINHA
# 279    DELEGACIA DE ADM.TRIBUTARIA DA RFB EM S.PAULO
# 291                DELEGACIA DA RFB EM CAXIAS DO SUL
# ...                                              ...
# 46679                DELEGACIA DA RFB EM SANTA MARIA
# 46683      SUPERINTENDENCIA REGIONAL DA RFB NA 5A RF
# 46900                   DELEGACIA DA RFB EM CAMPINAS
# 47296                   DELEGACIA DA RFB EM SANTAREM
# 47715      SUPERINTENDENCIA REGIONAL DA RFB NA 9A RF
#
#                                       Plano Orçamentário  \
# 8           ADMINISTRACAO DA UNIDADE - DESPESAS DIVERSAS
# 45                        ADMINISTRACAO DA UNIDADE - RFB
# 157                       ADMINISTRACAO DA UNIDADE - RFB
# 279                       ADMINISTRACAO DA UNIDADE - RFB
# 291                       ADMINISTRACAO DA UNIDADE - RFB
# ...                                                  ...
# 46679  INTERVENCOES NA LOGISTICA, ADEQUACAO E REFORMA...
# 46683  JULGAMENTO DE CAUSAS NA JUSTICA FEDERAL - DESP...
# 46900   OPERACOES DE FISCALIZACAO TRIBUTARIA E ADUANEIRA
# 47296                     ADMINISTRACAO DA UNIDADE - RFB
# 47715   OPERACOES DE FISCALIZACAO TRIBUTARIA E ADUANEIRA
#
#       Nome Categoria Econômica      Nome Grupo de Despesa  \
# 8           DESPESAS CORRENTES  Outras Despesas Correntes
# 45          DESPESAS CORRENTES  Outras Despesas Correntes
# 157         DESPESAS CORRENTES  Outras Despesas Correntes
# 279         DESPESAS CORRENTES  Outras Despesas Correntes
# 291         DESPESAS CORRENTES  Outras Despesas Correntes
# ...                        ...                        ...
# 46679      DESPESAS DE CAPITAL              Investimentos
# 46683       DESPESAS CORRENTES  Outras Despesas Correntes
# 46900       DESPESAS CORRENTES  Outras Despesas Correntes
# 47296       DESPESAS CORRENTES  Outras Despesas Correntes
# 47715       DESPESAS CORRENTES  Outras Despesas Correntes
#
#                           Nome Elemento de Despesa Modalidade da Despesa  \
# 8      Outros Serviços de Terceiros - Pessoa Juríd    Aplicações Diretas
# 45     Outros Serviços de Terceiros - Pessoa Juríd    Aplicações Diretas
# 157    Outros Serviços de Terceiros - Pessoa Físic    Aplicações Diretas
# 279    Outros Serviços de Terceiros - Pessoa Juríd    Aplicações Diretas
# 291    Outros Serviços de Terceiros - Pessoa Juríd    Aplicações Diretas
# ...                                            ...                   ...
# 46679                          Obras e Instalações    Aplicações Diretas
# 46683  Outros Serviços de Terceiros - Pessoa Juríd    Aplicações Diretas
# 46900  Outros Serviços de Terceiros - Pessoa Juríd    Aplicações Diretas
# 47296  Outros Serviços de Terceiros - Pessoa Juríd    Aplicações Diretas
# 47715                       Locação de Mão-de-Obra    Aplicações Diretas
#
#       Valor Empenhado (R$) Valor Liquidado (R$) Valor Pago (R$)  \
# 8                 43718,86                 0,00            0,00
# 45                    0,00                 0,00            0,00
# 157                 100,00                 0,00            0,00
# 279                 110,00                 3,46            3,46
# 291              456316,28                 0,00            0,00
# ...                    ...                  ...             ...
# 46679                 0,00                 0,00            0,00
# 46683                 0,00                 0,00            0,00
# 46900                 0,00                 0,00            0,00
# 47296              5000,00                 0,00            0,00
# 47715                 0,00                 0,00            0,00
#
#       Valor Restos a Pagar Inscritos (R$) Valor Restos a Pagar Cancelado (R$)  \
# 8                                    0,00                                0,00
# 45                                   0,00                                0,00
# 157                                  0,00                                0,00
# 279                                  0,00                                0,00
# 291                                  0,00                                0,00
# ...                                   ...                                 ...
# 46679                                0,00                                0,00
# 46683                                0,00                                0,00
# 46900                                0,00                                0,00
# 47296                                0,00                                0,00
# 47715                                0,00                                0,00
#
#       Valor Restos a Pagar Pagos (R$)
# 8                            46002,06
# 45                           43688,42
# 157                          69792,23
# 279                         357639,20
# 291                         334575,87
# ...                               ...
# 46679                       297674,75
# 46683                        15400,67
# 46900                         8845,51
# 47296                            0,00
# 47715                         6096,27
#
# [421 rows x 14 columns]
