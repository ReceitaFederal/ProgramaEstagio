# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/anaclara/.local/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: tzdata>=2022.7 in /home/anaclara/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/anaclara/.local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/anaclara/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
# Out:
# /tmp/ipykernel_4117/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('../../dados/dados_siape_bruto/descompactado/202311_Servidores_SIAPE/202311_Cadastro.csv', encoding='iso-8859-1', sep=';')
# Out:
# /tmp/ipykernel_4117/2897270729.py:1: DtypeWarning: Columns (2,5,7,9,34,36,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../dados/dados_siape_bruto/descompactado/202311_Servidores_SIAPE/202311_Cadastro.csv', encoding='iso-8859-1', sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748596 entries, 0 to 748595
# Data columns (total 43 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Id_SERVIDOR_PORTAL                    748596 non-null  int64
#  1   NOME                                  748596 non-null  object
#  2   CPF                                   712000 non-null  object
#  3   MATRICULA                             748596 non-null  object
#  4   DESCRICAO_CARGO                       748596 non-null  object
#  5   CLASSE_CARGO                          569395 non-null  object
#  6   REFERENCIA_CARGO                      712000 non-null  float64
#  7   PADRAO_CARGO                          441081 non-null  object
#  8   NIVEL_CARGO                           712000 non-null  float64
#  9   SIGLA_FUNCAO                          748596 non-null  object
#  10  NIVEL_FUNCAO                          748596 non-null  int64
#  11  FUNCAO                                748596 non-null  object
#  12  CODIGO_ATIVIDADE                      748596 non-null  int64
#  13  ATIVIDADE                             748596 non-null  object
#  14  OPCAO_PARCIAL                         59519 non-null   object
#  15  COD_UORG_LOTACAO                      748596 non-null  int64
#  16  UORG_LOTACAO                          748596 non-null  object
#  17  COD_ORG_LOTACAO                       748596 non-null  int64
#  18  ORG_LOTACAO                           748596 non-null  object
#  19  COD_ORGSUP_LOTACAO                    748596 non-null  int64
#  20  ORGSUP_LOTACAO                        748596 non-null  object
#  21  COD_UORG_EXERCICIO                    748596 non-null  int64
#  22  UORG_EXERCICIO                        748596 non-null  object
#  23  COD_ORG_EXERCICIO                     748596 non-null  int64
#  24  ORG_EXERCICIO                         748596 non-null  object
#  25  COD_ORGSUP_EXERCICIO                  748596 non-null  int64
#  26  ORGSUP_EXERCICIO                      748596 non-null  object
#  27  COD_TIPO_VINCULO                      748596 non-null  int64
#  28  TIPO_VINCULO                          748596 non-null  object
#  29  SITUACAO_VINCULO                      748596 non-null  object
#  30  DATA_INICIO_AFASTAMENTO               0 non-null       float64
#  31  DATA_TERMINO_AFASTAMENTO              0 non-null       float64
#  32  REGIME_JURIDICO                       748596 non-null  object
#  33  JORNADA_DE_TRABALHO                   748596 non-null  object
#  34  DATA_INGRESSO_CARGOFUNCAO             670498 non-null  object
#  35  DATA_NOMEACAO_CARGOFUNCAO             0 non-null       float64
#  36  DATA_INGRESSO_ORGAO                   711947 non-null  object
#  37  DOCUMENTO_INGRESSO_SERVICOPUBLICO     649248 non-null  object
#  38  DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO  651996 non-null  object
#  39  DIPLOMA_INGRESSO_CARGOFUNCAO          0 non-null       float64
#  40  DIPLOMA_INGRESSO_ORGAO                748596 non-null  object
#  41  DIPLOMA_INGRESSO_SERVICOPUBLICO       748596 non-null  object
#  42  UF_EXERCICIO                          748596 non-null  int64
# dtypes: float64(6), int64(11), object(26)
# memory usage: 245.6+ MB

# %%
df.sample(5)
# Out:
#         Id_SERVIDOR_PORTAL                                   NOME  \
# 369622           310630679                  JULIANO DA SILVA REIS
# 183416           312636400              EDSON LIMA DA PURIFICACAO
# 572641           310613276  RAFAELLA FERNANDA VILLA NOVA DA SILVA
# 93152            310486271                  BRUNO BELLAN HERINGER
# 141470           313097958             CRISTIANO CARDOSO DA SILVA
#
#                    CPF MATRICULA                         DESCRICAO_CARGO  \
# 369622  ***.535.100-**   023****                            Sem informaç
# 183416  ***.231.877-**   012****  ANALISTA TRIBUTARIO REC FEDERAL BRASIL
# 572641  ***.111.424-**   028****                     ASSISTENTE DE ALUNO
# 93152   ***.568.827-**   023****             ASSISTENTE EM ADMINISTRACAO
# 141470  ***.755.701-**   010****                  TECNICO ADMINISTRATIVO
#
#        CLASSE_CARGO  REFERENCIA_CARGO PADRAO_CARGO  NIVEL_CARGO SIGLA_FUNCAO  \
# 369622          NaN              -1.0           -1         -1.0           GF
# 183416            S               0.0          003          0.0           -1
# 572641            C               0.0          406          0.0           -1
# 93152             D               0.0          305          0.0           -1
# 141470            B               0.0           IV          0.0           -1
#
#         NIVEL_FUNCAO              FUNCAO  CODIGO_ATIVIDADE         ATIVIDADE  \
# 369622            27  FUNCAO GRATIFICADA               281  CHEFE DE UNIDADE
# 183416            -1      Sem informação                -1      Sem informaç
# 572641            -1      Sem informação                -1      Sem informaç
# 93152             -1      Sem informação                -1      Sem informaç
# 141470            -1      Sem informação                -1      Sem informaç
#
#        OPCAO_PARCIAL  COD_UORG_LOTACAO  \
# 369622             S    26443024000000
# 183416           NaN    17600000000671
# 572641           NaN    26418000000033
# 93152            NaN    26406000001176
# 141470           NaN    40701000001209
#
#                                     UORG_LOTACAO  COD_ORG_LOTACAO  \
# 369622            HOSPITAL UNIVERSITARIO DA UFSM            26443
# 183416  DEMAC/RJ/DEL ESP RFB MAIORES CONTRIBUINT            17600
# 572641            DIRECAO GERAL/CAMPUS BARREIROS            26418
# 93152                             CAMPUS VITORIA            26406
# 141470     DIRETORIA DE PLANEJ, ADM. E LOGISTICA            40701
#
#                                               ORG_LOTACAO  COD_ORGSUP_LOTACAO  \
# 369622        Empresa Brasileira de Serviços Hospitalares               15000
# 183416                              MINISTERIO DA FAZENDA               20101
# 572641                    Instituto Federal de Pernambuco               15000
# 93152                 Instituto Federal do Espírito Santo               15000
# 141470  Instituto Brasileiro do Meio Ambiente e Recurs...               40211
#
#                      ORGSUP_LOTACAO  COD_UORG_EXERCICIO  \
# 369622       Ministério da Educação                  -3
# 183416     Presidência da República      17600000000689
# 572641       Ministério da Educação      26418000000088
# 93152        Ministério da Educação      26406000001193
# 141470  MINISTERIO DO MEIO AMBIENTE      40701000001239
#
#                                   UORG_EXERCICIO  COD_ORG_EXERCICIO  \
# 369622                                  Inválido              26443
# 183416      EQUIPE GESTAO CRED TRIB E DIR CRED 5              17600
# 572641  COORD GERAL DE ASSIST AO ESTUDANTE/C BAR              26418
# 93152              COORD DE LICITACOES E COMPRAS              26406
# 141470  SERV. DE BENEF. APOSENTADORIAS E PENSOES              40701
#
#                                             ORG_EXERCICIO  \
# 369622        Empresa Brasileira de Serviços Hospitalares
# 183416                              MINISTERIO DA FAZENDA
# 572641                    Instituto Federal de Pernambuco
# 93152                 Instituto Federal do Espírito Santo
# 141470  Instituto Brasileiro do Meio Ambiente e Recurs...
#
#         COD_ORGSUP_EXERCICIO             ORGSUP_EXERCICIO  COD_TIPO_VINCULO  \
# 369622                 15000       Ministério da Educação                 1
# 183416                 20101     Presidência da República                 2
# 572641                 15000       Ministério da Educação                 2
# 93152                  15000       Ministério da Educação                 2
# 141470                 40211  MINISTERIO DO MEIO AMBIENTE                 2
#
#        TIPO_VINCULO     SITUACAO_VINCULO  DATA_INICIO_AFASTAMENTO  \
# 369622       Função  CELETISTA/EMPREGADO                      NaN
# 183416        Cargo     ATIVO PERMANENTE                      NaN
# 572641        Cargo     ATIVO PERMANENTE                      NaN
# 93152         Cargo     ATIVO PERMANENTE                      NaN
# 141470        Cargo     ATIVO PERMANENTE                      NaN
#
#         DATA_TERMINO_AFASTAMENTO                    REGIME_JURIDICO  \
# 369622                       NaN  CONSOLIDACAO DAS LEIS DO TRABALHO
# 183416                       NaN              REGIME JURIDICO UNICO
# 572641                       NaN              REGIME JURIDICO UNICO
# 93152                        NaN              REGIME JURIDICO UNICO
# 141470                       NaN              REGIME JURIDICO UNICO
#
#        JORNADA_DE_TRABALHO DATA_INGRESSO_CARGOFUNCAO  \
# 369622   40 HORAS SEMANAIS                08/03/2022
# 183416   40 HORAS SEMANAIS                30/12/2016
# 572641   40 HORAS SEMANAIS                12/11/2015
# 93152    40 HORAS SEMANAIS                12/05/2016
# 141470   40 HORAS SEMANAIS                12/05/2014
#
#         DATA_NOMEACAO_CARGOFUNCAO DATA_INGRESSO_ORGAO  \
# 369622                        NaN          01/12/2016
# 183416                        NaN          19/06/2023
# 572641                        NaN          15/02/2022
# 93152                         NaN          12/05/2016
# 141470                        NaN          25/04/2014
#
#        DOCUMENTO_INGRESSO_SERVICOPUBLICO DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO  \
# 369622                         000000000                           01/12/2016
# 183416                         000000007                           30/01/1998
# 572641                              2551                           12/11/2015
# 93152                                NaN                           12/05/2016
# 141470                         471_IBAMA                           12/05/2014
#
#         DIPLOMA_INGRESSO_CARGOFUNCAO DIPLOMA_INGRESSO_ORGAO  \
# 369622                           NaN               CONTRATO
# 183416                           NaN                    LEI
# 572641                           NaN               PORTARIA
# 93152                            NaN               PORTARIA
# 141470                           NaN               PORTARIA
#
#        DIPLOMA_INGRESSO_SERVICOPUBLICO  UF_EXERCICIO
# 369622                        CONTRATO            -1
# 183416                        PORTARIA            -1
# 572641                        PORTARIA            -1
# 93152                            CARTA            -1
# 141470                        PORTARIA            -1

# %%
df_agrupado = df.groupby('REGIME_JURIDICO').size().reset_index(name='Quantidade')

# %%
display(df_agrupado) 
display(df_agrupado.info())
# Out:
#                         REGIME_JURIDICO  Quantidade
# 0     CONSOLIDACAO DAS LEIS DO TRABALHO       94520
# 1                   CONTRATO TEMPORARIO       32044
# 2                               ESTAGIO       16821
# 3                       ESTAGIO EMPRESA          78
# 4         MEDICO - PROGRAMA MAIS MEDICO       15988
# 5                      MEDICO RESIDENTE       10331
# 6                     NATUREZA ESPECIAL         736
# 7                 REGIME JURIDICO UNICO      536933
# 8                        REGIME MILITAR         217
# 9   RESIDENCIA MEDICA COMUNIDADE E FAMI           1
# 10         RESIDENCIA MULTIPROFISSIONAL        4331
# 11                         Sem informaç       36596
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REGIME_JURIDICO  12 non-null     object
#  1   Quantidade       12 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 320.0+ bytes
# None

# %%
df.value_counts('REGIME_JURIDICO')
# Out:
# REGIME_JURIDICO
# REGIME JURIDICO UNICO                  536933
# CONSOLIDACAO DAS LEIS DO TRABALHO       94520
# Sem informaç                            36596
# CONTRATO TEMPORARIO                     32044
# ESTAGIO                                 16821
# MEDICO - PROGRAMA MAIS MEDICO           15988
# MEDICO RESIDENTE                        10331
# RESIDENCIA MULTIPROFISSIONAL             4331
# NATUREZA ESPECIAL                         736
# REGIME MILITAR                            217
# ESTAGIO EMPRESA                            78
# RESIDENCIA MEDICA COMUNIDADE E FAMI         1
# Name: count, dtype: int64

# %%
df_filtro = df[df['REGIME_JURIDICO'].str.contains('estagio empresa', case=False)]

# %%
display(df_filtro)
# Out:
#         Id_SERVIDOR_PORTAL                               NOME             CPF  \
# 504              313727419               ABNER VIEIRA PEREIRA  ***.490.347-**
# 35662            312003913                  AMANDA NUNES LIMA  ***.863.907-**
# 40473            311831443  ANA CLAUDIA FERREIRA LONGO MORAES  ***.616.557-**
# 45091            309921682       ANA LUIZA RODRIGUES DE SOUSA  ***.114.231-**
# 45227            311764784          ANA MARCIA INACIO CANDIDO  ***.271.337-**
# ...                    ...                                ...             ...
# 692323           311869259            VINICIUS RAMOS DA SILVA  ***.435.357-**
# 693732           313114388            VITOR FERREIRA DA SILVA  ***.210.997-**
# 705783           312143944                WILLIAM DIAS DUARTE  ***.277.517-**
# 708602           312095785            YAGO DE ARAUJO HENRIQUE  ***.680.087-**
# 709276           313172084            YASMIN BARROS DE AMORIM  ***.665.751-**
#
#        MATRICULA DESCRICAO_CARGO CLASSE_CARGO  REFERENCIA_CARGO PADRAO_CARGO  \
# 504      033****    Sem informaç          NaN              -1.0           -1
# 35662    033****    Sem informaç          NaN              -1.0           -1
# 40473    033****    Sem informaç          NaN              -1.0           -1
# 45091    010****        Inválido          NaN               0.0          NaN
# 45227    032****    Sem informaç          NaN              -1.0           -1
# ...          ...             ...          ...               ...          ...
# 692323   033****    Sem informaç          NaN              -1.0           -1
# 693732   033****    Sem informaç          NaN              -1.0           -1
# 705783   033****    Sem informaç          NaN              -1.0           -1
# 708602   033****    Sem informaç          NaN              -1.0           -1
# 709276   033****    Sem informaç          NaN              -1.0           -1
#
#         NIVEL_CARGO SIGLA_FUNCAO  NIVEL_FUNCAO           FUNCAO  \
# 504            -1.0          ETE             1  ESTAGIO EMPRESA
# 35662          -1.0          ETE             1  ESTAGIO EMPRESA
# 40473          -1.0          ETE             1  ESTAGIO EMPRESA
# 45091           0.0           -1            -1   Sem informação
# 45227          -1.0          ETE             1  ESTAGIO EMPRESA
# ...             ...          ...           ...              ...
# 692323         -1.0          ETE             1  ESTAGIO EMPRESA
# 693732         -1.0          ETE             1  ESTAGIO EMPRESA
# 705783         -1.0          ETE             1  ESTAGIO EMPRESA
# 708602         -1.0          ETE             2  ESTAGIO EMPRESA
# 709276         -1.0          ETE             1  ESTAGIO EMPRESA
#
#         CODIGO_ATIVIDADE     ATIVIDADE OPCAO_PARCIAL  COD_UORG_LOTACAO  \
# 504                 2473    ESTAGIARIO           NaN                -3
# 35662               2473    ESTAGIARIO           NaN                -3
# 40473               2473    ESTAGIARIO           NaN                -3
# 45091                 -1  Sem informaç           NaN                -3
# 45227               2473    ESTAGIARIO           NaN                -3
# ...                  ...           ...           ...               ...
# 692323              2473    ESTAGIARIO           NaN                -3
# 693732              2473    ESTAGIARIO           NaN                -3
# 705783              2473    ESTAGIARIO           NaN                -3
# 708602              2473    ESTAGIARIO           NaN                -3
# 709276              2473    ESTAGIARIO           NaN                -3
#
#        UORG_LOTACAO  COD_ORG_LOTACAO  \
# 504        Inválido            20302
# 35662      Inválido            20302
# 40473      Inválido            20302
# 45091      Inválido            22202
# 45227      Inválido            20302
# ...             ...              ...
# 692323     Inválido            20302
# 693732     Inválido            20302
# 705783     Inválido            20302
# 708602     Inválido            20302
# 709276     Inválido            20302
#
#                                         ORG_LOTACAO  COD_ORGSUP_LOTACAO  \
# 504                  Nuclebrás Equipamentos Pesados               32000
# 35662                Nuclebrás Equipamentos Pesados               32000
# 40473                Nuclebrás Equipamentos Pesados               32000
# 45091   Empresa Brasileira de Pesquisa Agropecuária               13000
# 45227                Nuclebrás Equipamentos Pesados               32000
# ...                                             ...                 ...
# 692323               Nuclebrás Equipamentos Pesados               32000
# 693732               Nuclebrás Equipamentos Pesados               32000
# 705783               Nuclebrás Equipamentos Pesados               32000
# 708602               Nuclebrás Equipamentos Pesados               32000
# 709276               Nuclebrás Equipamentos Pesados               32000
#
#                                            ORGSUP_LOTACAO  COD_UORG_EXERCICIO  \
# 504                         Ministério de Minas e Energia                  -3
# 35662                       Ministério de Minas e Energia                  -3
# 40473                       Ministério de Minas e Energia                  -3
# 45091   Ministério da Agricultura, Pecuária e Abasteci...      22202001380080
# 45227                       Ministério de Minas e Energia                  -3
# ...                                                   ...                 ...
# 692323                      Ministério de Minas e Energia                  -3
# 693732                      Ministério de Minas e Energia                  -3
# 705783                      Ministério de Minas e Energia                  -3
# 708602                      Ministério de Minas e Energia                  -3
# 709276                      Ministério de Minas e Energia                  -3
#
#                                  UORG_EXERCICIO  COD_ORG_EXERCICIO  \
# 504                                    Inválido              20302
# 35662                                  Inválido              20302
# 40473                                  Inválido              20302
# 45091   DEPARTAMENTO DE GESTAO DE PESSOAS - DGP              22202
# 45227                                  Inválido              20302
# ...                                         ...                ...
# 692323                                 Inválido              20302
# 693732                                 Inválido              20302
# 705783                                 Inválido              20302
# 708602                                 Inválido              20302
# 709276                                 Inválido              20302
#
#                                       ORG_EXERCICIO  COD_ORGSUP_EXERCICIO  \
# 504                  Nuclebrás Equipamentos Pesados                 32000
# 35662                Nuclebrás Equipamentos Pesados                 32000
# 40473                Nuclebrás Equipamentos Pesados                 32000
# 45091   Empresa Brasileira de Pesquisa Agropecuária                 13000
# 45227                Nuclebrás Equipamentos Pesados                 32000
# ...                                             ...                   ...
# 692323               Nuclebrás Equipamentos Pesados                 32000
# 693732               Nuclebrás Equipamentos Pesados                 32000
# 705783               Nuclebrás Equipamentos Pesados                 32000
# 708602               Nuclebrás Equipamentos Pesados                 32000
# 709276               Nuclebrás Equipamentos Pesados                 32000
#
#                                          ORGSUP_EXERCICIO  COD_TIPO_VINCULO  \
# 504                         Ministério de Minas e Energia                 1
# 35662                       Ministério de Minas e Energia                 1
# 40473                       Ministério de Minas e Energia                 1
# 45091   Ministério da Agricultura, Pecuária e Abasteci...                 3
# 45227                       Ministério de Minas e Energia                 1
# ...                                                   ...               ...
# 692323                      Ministério de Minas e Energia                 1
# 693732                      Ministério de Minas e Energia                 1
# 705783                      Ministério de Minas e Energia                 1
# 708602                      Ministério de Minas e Energia                 1
# 709276                      Ministério de Minas e Energia                 1
#
#        TIPO_VINCULO    SITUACAO_VINCULO  DATA_INICIO_AFASTAMENTO  \
# 504          Função  ESTAGIARIO EMPRESA                      NaN
# 35662        Função  ESTAGIARIO EMPRESA                      NaN
# 40473        Função  ESTAGIARIO EMPRESA                      NaN
# 45091        Outros  ESTAGIARIO EMPRESA                      NaN
# 45227        Função  ESTAGIARIO EMPRESA                      NaN
# ...             ...                 ...                      ...
# 692323       Função  ESTAGIARIO EMPRESA                      NaN
# 693732       Função  ESTAGIARIO EMPRESA                      NaN
# 705783       Função  ESTAGIARIO EMPRESA                      NaN
# 708602       Função  ESTAGIARIO EMPRESA                      NaN
# 709276       Função  ESTAGIARIO EMPRESA                      NaN
#
#         DATA_TERMINO_AFASTAMENTO  REGIME_JURIDICO JORNADA_DE_TRABALHO  \
# 504                          NaN  ESTAGIO EMPRESA   30 HORAS SEMANAIS
# 35662                        NaN  ESTAGIO EMPRESA   30 HORAS SEMANAIS
# 40473                        NaN  ESTAGIO EMPRESA   30 HORAS SEMANAIS
# 45091                        NaN  ESTAGIO EMPRESA   20 HORAS SEMANAIS
# 45227                        NaN  ESTAGIO EMPRESA   30 HORAS SEMANAIS
# ...                          ...              ...                 ...
# 692323                       NaN  ESTAGIO EMPRESA   30 HORAS SEMANAIS
# 693732                       NaN  ESTAGIO EMPRESA   30 HORAS SEMANAIS
# 705783                       NaN  ESTAGIO EMPRESA   30 HORAS SEMANAIS
# 708602                       NaN  ESTAGIO EMPRESA   30 HORAS SEMANAIS
# 709276                       NaN  ESTAGIO EMPRESA   30 HORAS SEMANAIS
#
#        DATA_INGRESSO_CARGOFUNCAO  DATA_NOMEACAO_CARGOFUNCAO  \
# 504                   01/11/2023                        NaN
# 35662                 24/07/2023                        NaN
# 40473                 24/07/2023                        NaN
# 45091                        NaN                        NaN
# 45227                 12/01/2022                        NaN
# ...                          ...                        ...
# 692323                09/09/2022                        NaN
# 693732                25/10/2022                        NaN
# 705783                13/04/2023                        NaN
# 708602                14/09/2023                        NaN
# 709276                19/01/2023                        NaN
#
#        DATA_INGRESSO_ORGAO DOCUMENTO_INGRESSO_SERVICOPUBLICO  \
# 504             01/11/2023                               NaN
# 35662           24/07/2023                               NaN
# 40473           24/07/2023                               NaN
# 45091           30/07/2014                               NaN
# 45227           12/01/2022                               NaN
# ...                    ...                               ...
# 692323          09/09/2022                               NaN
# 693732          25/10/2022                               NaN
# 705783          13/04/2023                               NaN
# 708602          14/09/2023                               NaN
# 709276          19/01/2023                               NaN
#
#        DATA_DIPLOMA_INGRESSO_SERVICOPUBLICO  DIPLOMA_INGRESSO_CARGOFUNCAO  \
# 504                                     NaN                           NaN
# 35662                                   NaN                           NaN
# 40473                                   NaN                           NaN
# 45091                                   NaN                           NaN
# 45227                                   NaN                           NaN
# ...                                     ...                           ...
# 692323                                  NaN                           NaN
# 693732                                  NaN                           NaN
# 705783                                  NaN                           NaN
# 708602                                  NaN                           NaN
# 709276                                  NaN                           NaN
#
#        DIPLOMA_INGRESSO_ORGAO DIPLOMA_INGRESSO_SERVICOPUBLICO  UF_EXERCICIO
# 504                  CONTRATO                        Inválido            -1
# 35662                CONTRATO                        Inválido            -1
# 40473                CONTRATO                        Inválido            -1
# 45091                     LEI                        Inválido            -1
# 45227                CONTRATO                        Inválido            -1
# ...                       ...                             ...           ...
# 692323               CONTRATO                        Inválido            -1
# 693732               CONTRATO                        Inválido            -1
# 705783               CONTRATO                        Inválido            -1
# 708602               CONTRATO                        Inválido            -1
# 709276               CONTRATO                        Inválido            -1
#
# [78 rows x 43 columns]

# %%
v = 'oi'
display(type(df.groupby('REGIME_JURIDICO').size().reset_index()))
# Out:
# pandas.core.frame.DataFrame

# %%
df[]

# %%
lista = [1, 2, 3, 'abelha', 'mel', 1.2]

for item in lista:
    display (f'{item}: {type(item)}')
# Out:
# "1: <class 'int'>"
# "2: <class 'int'>"
# "3: <class 'int'>"
# "abelha: <class 'str'>"
# "mel: <class 'str'>"
# "1.2: <class 'float'>"

# %%
lista[3]
# Out:
# 'abelha'

# %%
import pandas as pd

# Dados
dados = {
    'País': ['Brasil', 'Argentina', 'Estados Unidos', 'China', 'Índia'],
    'Continente': ['América do Sul', 'América do Sul', 'América do Norte', 'Ásia', 'Ásia'],
    'População (milhões)': [211, 45, 331, 1441, 1380]
}

# Criar DataFrame
df = pd.DataFrame(dados)

# Exibir DataFrame
display(df)
# Out:
#              País        Continente  População (milhões)
# 0          Brasil    América do Sul                  211
# 1       Argentina    América do Sul                   45
# 2  Estados Unidos  América do Norte                  331
# 3           China              Ásia                 1441
# 4           Índia              Ásia                 1380

# %%
df['nova coluna'] = 'abelha'

display(df)
# Out:
#              País        Continente  População (milhões) nova coluna
# 0          Brasil    América do Sul                  211      abelha
# 1       Argentina    América do Sul                   45      abelha
# 2  Estados Unidos  América do Norte                  331      abelha
# 3           China              Ásia                 1441      abelha
# 4           Índia              Ásia                 1380      abelha

# %%
display (type(df['País']))
display (type(df[['País']]))
display (type(df[['País', 'População (milhões)']]))
# Out:
# pandas.core.series.Series
# pandas.core.frame.DataFrame
# pandas.core.frame.DataFrame

# %%
df[[True, False, False, False, True]]
# Out:
#      País      Continente  População (milhões)
# 0  Brasil  América do Sul                  211
# 4   Índia            Ásia                 1380

# %% [markdown]
# # Passando os índices diretamente na função VERSUS passando por uma variável
# ## são equivalentes
#
# vai depende ser vai usar a varíavel em outros lugares

# %%
series_contem_bra = df['País'].str.contains('Bra')
df[series_contem_bra
# Out:
#      País      Continente  População (milhões)
# 0  Brasil  América do Sul                  211

# %% [markdown]
# ## mais comum dessa forma abaixo

# %%
df[df['País'].str.contains('Bra')]
# Out:
#      País      Continente  População (milhões)
# 0  Brasil  América do Sul                  211

# %%
df['País'].str.contains('r')
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: País, dtype: bool

# %%
df['População (milhões)'] > 200
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: População (milhões), dtype: bool

# %%
df['País'].str.contains('r') & (df['População (milhões)'] > 200)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3801         try:
# -> 3802             return self._engine.get_loc(casted_key)
#    3803         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'País'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4117/789855584.py in <module>
# ----> 1 df['País'].str.contains('r') & (df['População (milhões)'] > 200)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    4088             if self.columns.nlevels > 1:
#    4089                 return self._getitem_multilevel(key)
# -> 4090             indexer = self.columns.get_loc(key)
#    4091             if is_integer(indexer):
#    4092                 indexer = [indexer]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3807             ):
#    3808                 raise InvalidIndexError(key)
# -> 3809             raise KeyError(key) from err
#    3810         except TypeError:
#    3811             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'País'
